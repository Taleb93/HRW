# %%
import os
import cv2

# Pfade anpassen
image_folder = r"C:\Uni\python\data\Klassifikation\33_VorgeschriebeneFahrtrichtungRechts\33"
label_folder = r"C:\Uni\python\data\Klassifikation\33_labels\yolo_labels\renamed_labels"
output_folder = r"C:\Uni\python\data\Klassifikation\33_cropped_images"

# Output-Ordner erstellen, falls nicht vorhanden
os.makedirs(output_folder, exist_ok=True)

# Bild- und Label-Verarbeitung
for label_file in os.listdir(label_folder):
    if label_file.endswith(".txt"):  # Nur Label-Dateien verarbeiten
        image_name = os.path.splitext(label_file)[0] + ".png"  # Erwarte Bildformat .png
        image_path = os.path.join(image_folder, image_name)
        label_path = os.path.join(label_folder, label_file)

        # Bild laden
        if os.path.exists(image_path):
            image = cv2.imread(image_path)
            h, w, _ = image.shape  # Höhe und Breite des Bildes

            # Labels laden und zuschneiden
            with open(label_path, "r") as file:
                lines = file.readlines()
                for line in lines:
                    class_id, x_center, y_center, width, height = map(float, line.strip().split())

                    # YOLO-Koordinaten in Pixel umrechnen
                    x_center, y_center = int(x_center * w), int(y_center * h)
                    width, height = int(width * w), int(height * h)
                    x1, y1 = max(0, x_center - width // 2), max(0, y_center - height // 2)
                    x2, y2 = min(w, x_center + width // 2), min(h, y_center + height // 2)

                    # Zuschneiden und speichern
                    cropped_image = image[y1:y2, x1:x2]
                    output_path = os.path.join(output_folder, f"{os.path.splitext(image_name)[0]}_cropped.png")
                    cv2.imwrite(output_path, cropped_image)
        else:
            print(f"Bild {image_name} nicht gefunden!")

# %%
import os
import shutil

# Pfade anpassen
image_folder = r"C:\Uni\python\data\Klassifikation\33_cropped_images"
label_folder = r"C:\Uni\python\data\Klassifikation\33_labels\yolo_labels\renamed_labels"
output_folder = r"C:\Uni\python\data\Klassifikation\classification_ready"

# Output-Ordner erstellen
os.makedirs(output_folder, exist_ok=True)

# Bilder nach Klassen sortieren
for label_file in os.listdir(label_folder):
    if label_file.endswith(".txt"):
        image_name = os.path.splitext(label_file)[0] + "_cropped.png"
        image_path = os.path.join(image_folder, image_name)
        label_path = os.path.join(label_folder, label_file)

        if os.path.exists(image_path):
            # Klassen-ID aus dem Label lesen
            with open(label_path, "r") as file:
                first_line = file.readline()
                class_id = first_line.split()[0]  # Erste Zahl ist die Klassen-ID

            # Klasse als Ordner erstellen
            class_folder = os.path.join(output_folder, class_id)
            os.makedirs(class_folder, exist_ok=True)

            # Bild in den Klassenordner verschieben
            shutil.move(image_path, os.path.join(class_folder, image_name))
        else:
            print(f"Bild {image_name} nicht gefunden!")

# %%
import os

# Eingabeparameter
image_folder = r"C:\Uni\python\data\Klassifikation\37_VorgeschriebeneFahrtrichtungGeradeausOderLinks\renamed_images"
label_folder = r"C:\Uni\python\data\Klassifikation\37_labels\yolo_labels\renamed_labels"
prefix_or_suffix = input("Geben Sie den Präfix oder Suffix ein (z.B. 'r_'): ")
add_to_start = input("Soll der Text am Anfang (ja/nein)? ").strip().lower() == "ja"

def rename_files(folder, prefix_or_suffix, add_to_start):
    # Alle Dateien im Ordner durchgehen
    for filename in os.listdir(folder):
        old_path = os.path.join(folder, filename)
        if os.path.isfile(old_path):  # Nur Dateien bearbeiten
            name, ext = os.path.splitext(filename)
            # Neuen Namen erstellen
            if add_to_start:
                new_name = f"{prefix_or_suffix}{name}{ext}"
            else:
                new_name = f"{name}{prefix_or_suffix}{ext}"
            new_path = os.path.join(folder, new_name)
            # Datei umbenennen
            os.rename(old_path, new_path)
            print(f"{filename} wurde in {new_name} umbenannt.")

# Bilder umbenennen
print("Bilder werden umbenannt...")
rename_files(image_folder, prefix_or_suffix, add_to_start)

# Labels umbenennen
print("Labels werden umbenannt...")
rename_files(label_folder, prefix_or_suffix, add_to_start)

print("Umbenennen abgeschlossen.")
# Out:
# Bilder werden umbenannt...
# 2000.png wurde in 2000_GL.png umbenannt.
# 2001.png wurde in 2001_GL.png umbenannt.
# 2002.png wurde in 2002_GL.png umbenannt.
# 2003.png wurde in 2003_GL.png umbenannt.
# 2004.png wurde in 2004_GL.png umbenannt.
# 2005.png wurde in 2005_GL.png umbenannt.
# 2006.png wurde in 2006_GL.png umbenannt.
# 2007.png wurde in 2007_GL.png umbenannt.
# 2008.png wurde in 2008_GL.png umbenannt.
# 2009.png wurde in 2009_GL.png umbenannt.
# 2010.png wurde in 2010_GL.png umbenannt.
# 2011.png wurde in 2011_GL.png umbenannt.
# 2012.png wurde in 2012_GL.png umbenannt.
# 2013.png wurde in 2013_GL.png umbenannt.
# 2014.png wurde in 2014_GL.png umbenannt.
# 2015.png wurde in 2015_GL.png umbenannt.
# 2016.png wurde in 2016_GL.png umbenannt.
# 2017.png wurde in 2017_GL.png umbenannt.
# 2018.png wurde in 2018_GL.png umbenannt.
# 2019.png wurde in 2019_GL.png umbenannt.
# 2020.png wurde in 2020_GL.png umbenannt.
# 2021.png wurde in 2021_GL.png umbenannt.
# 2022.png wurde in 2022_GL.png umbenannt.
# 2023.png wurde in 2023_GL.png umbenannt.
# 2024.png wurde in 2024_GL.png umbenannt.
# 2025.png wurde in 2025_GL.png umbenannt.
# 2026.png wurde in 2026_GL.png umbenannt.
# 2027.png wurde in 2027_GL.png umbenannt.
# 2028.png wurde in 2028_GL.png umbenannt.
# 2029.png wurde in 2029_GL.png umbenannt.
# 2030.png wurde in 2030_GL.png umbenannt.
# 2031.png wurde in 2031_GL.png umbenannt.
# 2032.png wurde in 2032_GL.png umbenannt.
# 2033.png wurde in 2033_GL.png umbenannt.
# 2034.png wurde in 2034_GL.png umbenannt.
# 2035.png wurde in 2035_GL.png umbenannt.
# 2036.png wurde in 2036_GL.png umbenannt.
# 2037.png wurde in 2037_GL.png umbenannt.
# 2038.png wurde in 2038_GL.png umbenannt.
# 2039.png wurde in 2039_GL.png umbenannt.
# 2040.png wurde in 2040_GL.png umbenannt.
# 2041.png wurde in 2041_GL.png umbenannt.
# 2042.png wurde in 2042_GL.png umbenannt.
# 2043.png wurde in 2043_GL.png umbenannt.
# 2044.png wurde in 2044_GL.png umbenannt.
# 2045.png wurde in 2045_GL.png umbenannt.
# 2046.png wurde in 2046_GL.png umbenannt.
# 2047.png wurde in 2047_GL.png umbenannt.
# 2048.png wurde in 2048_GL.png umbenannt.
# 2049.png wurde in 2049_GL.png umbenannt.
# 2050.png wurde in 2050_GL.png umbenannt.
# 2051.png wurde in 2051_GL.png umbenannt.
# 2052.png wurde in 2052_GL.png umbenannt.
# 2053.png wurde in 2053_GL.png umbenannt.
# 2054.png wurde in 2054_GL.png umbenannt.
# 2055.png wurde in 2055_GL.png umbenannt.
# 2056.png wurde in 2056_GL.png umbenannt.
# 2057.png wurde in 2057_GL.png umbenannt.
# 2058.png wurde in 2058_GL.png umbenannt.
# 2059.png wurde in 2059_GL.png umbenannt.
# 2060.png wurde in 2060_GL.png umbenannt.
# 2061.png wurde in 2061_GL.png umbenannt.
# 2062.png wurde in 2062_GL.png umbenannt.
# 2063.png wurde in 2063_GL.png umbenannt.
# 2064.png wurde in 2064_GL.png umbenannt.
# 2065.png wurde in 2065_GL.png umbenannt.
# 2066.png wurde in 2066_GL.png umbenannt.
# 2067.png wurde in 2067_GL.png umbenannt.
# 2068.png wurde in 2068_GL.png umbenannt.
# 2069.png wurde in 2069_GL.png umbenannt.
# 2070.png wurde in 2070_GL.png umbenannt.
# 2071.png wurde in 2071_GL.png umbenannt.
# 2072.png wurde in 2072_GL.png umbenannt.
# 2073.png wurde in 2073_GL.png umbenannt.
# 2074.png wurde in 2074_GL.png umbenannt.
# 2075.png wurde in 2075_GL.png umbenannt.
# 2076.png wurde in 2076_GL.png umbenannt.
# 2077.png wurde in 2077_GL.png umbenannt.
# 2078.png wurde in 2078_GL.png umbenannt.
# 2079.png wurde in 2079_GL.png umbenannt.
# 2080.png wurde in 2080_GL.png umbenannt.
# 2081.png wurde in 2081_GL.png umbenannt.
# 2082.png wurde in 2082_GL.png umbenannt.
# 2083.png wurde in 2083_GL.png umbenannt.
# 2084.png wurde in 2084_GL.png umbenannt.
# 2085.png wurde in 2085_GL.png umbenannt.
# 2086.png wurde in 2086_GL.png umbenannt.
# 2087.png wurde in 2087_GL.png umbenannt.
# 2088.png wurde in 2088_GL.png umbenannt.
# 2089.png wurde in 2089_GL.png umbenannt.
# 2090.png wurde in 2090_GL.png umbenannt.
# 2091.png wurde in 2091_GL.png umbenannt.
# 2092.png wurde in 2092_GL.png umbenannt.
# 2093.png wurde in 2093_GL.png umbenannt.
# 2094.png wurde in 2094_GL.png umbenannt.
# 2095.png wurde in 2095_GL.png umbenannt.
# 2096.png wurde in 2096_GL.png umbenannt.
# 2097.png wurde in 2097_GL.png umbenannt.
# 2098.png wurde in 2098_GL.png umbenannt.
# 2099.png wurde in 2099_GL.png umbenannt.
# 2100.png wurde in 2100_GL.png umbenannt.
# 2101.png wurde in 2101_GL.png umbenannt.
# 2102.png wurde in 2102_GL.png umbenannt.
# 2103.png wurde in 2103_GL.png umbenannt.
# 2104.png wurde in 2104_GL.png umbenannt.
# 2105.png wurde in 2105_GL.png umbenannt.
# 2106.png wurde in 2106_GL.png umbenannt.
# 2107.png wurde in 2107_GL.png umbenannt.
# 2108.png wurde in 2108_GL.png umbenannt.
# 2109.png wurde in 2109_GL.png umbenannt.
# 2110.png wurde in 2110_GL.png umbenannt.
# 2111.png wurde in 2111_GL.png umbenannt.
# 2112.png wurde in 2112_GL.png umbenannt.
# 2113.png wurde in 2113_GL.png umbenannt.
# 2114.png wurde in 2114_GL.png umbenannt.
# 2115.png wurde in 2115_GL.png umbenannt.
# 2116.png wurde in 2116_GL.png umbenannt.
# 2117.png wurde in 2117_GL.png umbenannt.
# 2118.png wurde in 2118_GL.png umbenannt.
# 2119.png wurde in 2119_GL.png umbenannt.
# 2120.png wurde in 2120_GL.png umbenannt.
# 2121.png wurde in 2121_GL.png umbenannt.
# 2122.png wurde in 2122_GL.png umbenannt.
# 2123.png wurde in 2123_GL.png umbenannt.
# 2124.png wurde in 2124_GL.png umbenannt.
# 2125.png wurde in 2125_GL.png umbenannt.
# 2126.png wurde in 2126_GL.png umbenannt.
# 2127.png wurde in 2127_GL.png umbenannt.
# 2128.png wurde in 2128_GL.png umbenannt.
# 2129.png wurde in 2129_GL.png umbenannt.
# 2130.png wurde in 2130_GL.png umbenannt.
# 2131.png wurde in 2131_GL.png umbenannt.
# 2132.png wurde in 2132_GL.png umbenannt.
# 2133.png wurde in 2133_GL.png umbenannt.
# 2134.png wurde in 2134_GL.png umbenannt.
# 2135.png wurde in 2135_GL.png umbenannt.
# 2136.png wurde in 2136_GL.png umbenannt.
# 2137.png wurde in 2137_GL.png umbenannt.
# 2138.png wurde in 2138_GL.png umbenannt.
# 2139.png wurde in 2139_GL.png umbenannt.
# 2140.png wurde in 2140_GL.png umbenannt.
# 2141.png wurde in 2141_GL.png umbenannt.
# 2142.png wurde in 2142_GL.png umbenannt.
# 2143.png wurde in 2143_GL.png umbenannt.
# 2144.png wurde in 2144_GL.png umbenannt.
# 2145.png wurde in 2145_GL.png umbenannt.
# 2146.png wurde in 2146_GL.png umbenannt.
# 2147.png wurde in 2147_GL.png umbenannt.
# 2148.png wurde in 2148_GL.png umbenannt.
# 2149.png wurde in 2149_GL.png umbenannt.
# 2150.png wurde in 2150_GL.png umbenannt.
# 2151.png wurde in 2151_GL.png umbenannt.
# 2152.png wurde in 2152_GL.png umbenannt.
# 2153.png wurde in 2153_GL.png umbenannt.
# 2154.png wurde in 2154_GL.png umbenannt.
# 2155.png wurde in 2155_GL.png umbenannt.
# 2156.png wurde in 2156_GL.png umbenannt.
# 2157.png wurde in 2157_GL.png umbenannt.
# 2158.png wurde in 2158_GL.png umbenannt.
# 2159.png wurde in 2159_GL.png umbenannt.
# 2160.png wurde in 2160_GL.png umbenannt.
# 2161.png wurde in 2161_GL.png umbenannt.
# 2162.png wurde in 2162_GL.png umbenannt.
# 2163.png wurde in 2163_GL.png umbenannt.
# 2164.png wurde in 2164_GL.png umbenannt.
# 2165.png wurde in 2165_GL.png umbenannt.
# 2166.png wurde in 2166_GL.png umbenannt.
# 2167.png wurde in 2167_GL.png umbenannt.
# 2168.png wurde in 2168_GL.png umbenannt.
# 2169.png wurde in 2169_GL.png umbenannt.
# 2170.png wurde in 2170_GL.png umbenannt.
# 2171.png wurde in 2171_GL.png umbenannt.
# 2172.png wurde in 2172_GL.png umbenannt.
# 2173.png wurde in 2173_GL.png umbenannt.
# 2174.png wurde in 2174_GL.png umbenannt.
# 2175.png wurde in 2175_GL.png umbenannt.
# 2176.png wurde in 2176_GL.png umbenannt.
# 2177.png wurde in 2177_GL.png umbenannt.
# 2178.png wurde in 2178_GL.png umbenannt.
# 2179.png wurde in 2179_GL.png umbenannt.
# 2180.png wurde in 2180_GL.png umbenannt.
# 2181.png wurde in 2181_GL.png umbenannt.
# 2182.png wurde in 2182_GL.png umbenannt.
# 2183.png wurde in 2183_GL.png umbenannt.
# 2184.png wurde in 2184_GL.png umbenannt.
# 2185.png wurde in 2185_GL.png umbenannt.
# 2186.png wurde in 2186_GL.png umbenannt.
# 2187.png wurde in 2187_GL.png umbenannt.
# 2188.png wurde in 2188_GL.png umbenannt.
# 2189.png wurde in 2189_GL.png umbenannt.
# 2190.png wurde in 2190_GL.png umbenannt.
# 2191.png wurde in 2191_GL.png umbenannt.
# 2192.png wurde in 2192_GL.png umbenannt.
# 2193.png wurde in 2193_GL.png umbenannt.
# 2194.png wurde in 2194_GL.png umbenannt.
# 2195.png wurde in 2195_GL.png umbenannt.
# 2196.png wurde in 2196_GL.png umbenannt.
# 2197.png wurde in 2197_GL.png umbenannt.
# 2198.png wurde in 2198_GL.png umbenannt.
# 2199.png wurde in 2199_GL.png umbenannt.
# 2200.png wurde in 2200_GL.png umbenannt.
# 2201.png wurde in 2201_GL.png umbenannt.
# 2202.png wurde in 2202_GL.png umbenannt.
# 2203.png wurde in 2203_GL.png umbenannt.
# 2204.png wurde in 2204_GL.png umbenannt.
# 2205.png wurde in 2205_GL.png umbenannt.
# 2206.png wurde in 2206_GL.png umbenannt.
# 2207.png wurde in 2207_GL.png umbenannt.
# 2208.png wurde in 2208_GL.png umbenannt.
# 2209.png wurde in 2209_GL.png umbenannt.
# 2210.png wurde in 2210_GL.png umbenannt.
# 2211.png wurde in 2211_GL.png umbenannt.
# 2212.png wurde in 2212_GL.png umbenannt.
# 2213.png wurde in 2213_GL.png umbenannt.
# 2214.png wurde in 2214_GL.png umbenannt.
# 2215.png wurde in 2215_GL.png umbenannt.
# 2216.png wurde in 2216_GL.png umbenannt.
# 2217.png wurde in 2217_GL.png umbenannt.
# 2218.png wurde in 2218_GL.png umbenannt.
# 2219.png wurde in 2219_GL.png umbenannt.
# 2220.png wurde in 2220_GL.png umbenannt.
# 2221.png wurde in 2221_GL.png umbenannt.
# 2222.png wurde in 2222_GL.png umbenannt.
# 2223.png wurde in 2223_GL.png umbenannt.
# 2224.png wurde in 2224_GL.png umbenannt.
# 2225.png wurde in 2225_GL.png umbenannt.
# 2226.png wurde in 2226_GL.png umbenannt.
# 2227.png wurde in 2227_GL.png umbenannt.
# 2228.png wurde in 2228_GL.png umbenannt.
# 2229.png wurde in 2229_GL.png umbenannt.
# 2230.png wurde in 2230_GL.png umbenannt.
# 2231.png wurde in 2231_GL.png umbenannt.
# 2232.png wurde in 2232_GL.png umbenannt.
# 2233.png wurde in 2233_GL.png umbenannt.
# 2234.png wurde in 2234_GL.png umbenannt.
# 2235.png wurde in 2235_GL.png umbenannt.
# 2236.png wurde in 2236_GL.png umbenannt.
# 2237.png wurde in 2237_GL.png umbenannt.
# 2238.png wurde in 2238_GL.png umbenannt.
# 2239.png wurde in 2239_GL.png umbenannt.
# 2240.png wurde in 2240_GL.png umbenannt.
# 2241.png wurde in 2241_GL.png umbenannt.
# 2242.png wurde in 2242_GL.png umbenannt.
# 2243.png wurde in 2243_GL.png umbenannt.
# 2244.png wurde in 2244_GL.png umbenannt.
# 2245.png wurde in 2245_GL.png umbenannt.
# 2246.png wurde in 2246_GL.png umbenannt.
# 2247.png wurde in 2247_GL.png umbenannt.
# 2248.png wurde in 2248_GL.png umbenannt.
# 2249.png wurde in 2249_GL.png umbenannt.
# 2250.png wurde in 2250_GL.png umbenannt.
# 2251.png wurde in 2251_GL.png umbenannt.
# 2252.png wurde in 2252_GL.png umbenannt.
# 2253.png wurde in 2253_GL.png umbenannt.
# 2254.png wurde in 2254_GL.png umbenannt.
# 2255.png wurde in 2255_GL.png umbenannt.
# 2256.png wurde in 2256_GL.png umbenannt.
# 2257.png wurde in 2257_GL.png umbenannt.
# 2258.png wurde in 2258_GL.png umbenannt.
# 2259.png wurde in 2259_GL.png umbenannt.
# 2260.png wurde in 2260_GL.png umbenannt.
# 2261.png wurde in 2261_GL.png umbenannt.
# 2262.png wurde in 2262_GL.png umbenannt.
# 2263.png wurde in 2263_GL.png umbenannt.
# 2264.png wurde in 2264_GL.png umbenannt.
# 2265.png wurde in 2265_GL.png umbenannt.
# 2266.png wurde in 2266_GL.png umbenannt.
# 2267.png wurde in 2267_GL.png umbenannt.
# 2268.png wurde in 2268_GL.png umbenannt.
# 2269.png wurde in 2269_GL.png umbenannt.
# 2270.png wurde in 2270_GL.png umbenannt.
# 2271.png wurde in 2271_GL.png umbenannt.
# 2272.png wurde in 2272_GL.png umbenannt.
# 2273.png wurde in 2273_GL.png umbenannt.
# 2274.png wurde in 2274_GL.png umbenannt.
# 2275.png wurde in 2275_GL.png umbenannt.
# 2276.png wurde in 2276_GL.png umbenannt.
# 2277.png wurde in 2277_GL.png umbenannt.
# 2278.png wurde in 2278_GL.png umbenannt.
# 2279.png wurde in 2279_GL.png umbenannt.
# 2280.png wurde in 2280_GL.png umbenannt.
# 2281.png wurde in 2281_GL.png umbenannt.
# 2282.png wurde in 2282_GL.png umbenannt.
# 2283.png wurde in 2283_GL.png umbenannt.
# 2284.png wurde in 2284_GL.png umbenannt.
# 2285.png wurde in 2285_GL.png umbenannt.
# 2286.png wurde in 2286_GL.png umbenannt.
# 2287.png wurde in 2287_GL.png umbenannt.
# 2288.png wurde in 2288_GL.png umbenannt.
# 2289.png wurde in 2289_GL.png umbenannt.
# 2290.png wurde in 2290_GL.png umbenannt.
# 2291.png wurde in 2291_GL.png umbenannt.
# 2292.png wurde in 2292_GL.png umbenannt.
# 2293.png wurde in 2293_GL.png umbenannt.
# 2294.png wurde in 2294_GL.png umbenannt.
# 2295.png wurde in 2295_GL.png umbenannt.
# 2296.png wurde in 2296_GL.png umbenannt.
# 2297.png wurde in 2297_GL.png umbenannt.
# 2298.png wurde in 2298_GL.png umbenannt.
# 2299.png wurde in 2299_GL.png umbenannt.
# 2300.png wurde in 2300_GL.png umbenannt.
# 2301.png wurde in 2301_GL.png umbenannt.
# 2302.png wurde in 2302_GL.png umbenannt.
# 2303.png wurde in 2303_GL.png umbenannt.
# 2304.png wurde in 2304_GL.png umbenannt.
# 2305.png wurde in 2305_GL.png umbenannt.
# 2306.png wurde in 2306_GL.png umbenannt.
# 2307.png wurde in 2307_GL.png umbenannt.
# 2308.png wurde in 2308_GL.png umbenannt.
# 2309.png wurde in 2309_GL.png umbenannt.
# 2310.png wurde in 2310_GL.png umbenannt.
# 2311.png wurde in 2311_GL.png umbenannt.
# 2312.png wurde in 2312_GL.png umbenannt.
# 2313.png wurde in 2313_GL.png umbenannt.
# 2314.png wurde in 2314_GL.png umbenannt.
# 2315.png wurde in 2315_GL.png umbenannt.
# 2316.png wurde in 2316_GL.png umbenannt.
# 2317.png wurde in 2317_GL.png umbenannt.
# 2318.png wurde in 2318_GL.png umbenannt.
# 2319.png wurde in 2319_GL.png umbenannt.
# 2320.png wurde in 2320_GL.png umbenannt.
# 2321.png wurde in 2321_GL.png umbenannt.
# 2322.png wurde in 2322_GL.png umbenannt.
# 2323.png wurde in 2323_GL.png umbenannt.
# 2324.png wurde in 2324_GL.png umbenannt.
# 2325.png wurde in 2325_GL.png umbenannt.
# 2326.png wurde in 2326_GL.png umbenannt.
# 2327.png wurde in 2327_GL.png umbenannt.
# 2328.png wurde in 2328_GL.png umbenannt.
# 2329.png wurde in 2329_GL.png umbenannt.
# 2330.png wurde in 2330_GL.png umbenannt.
# 2331.png wurde in 2331_GL.png umbenannt.
# 2332.png wurde in 2332_GL.png umbenannt.
# 2333.png wurde in 2333_GL.png umbenannt.
# 2334.png wurde in 2334_GL.png umbenannt.
# 2335.png wurde in 2335_GL.png umbenannt.
# 2336.png wurde in 2336_GL.png umbenannt.
# 2337.png wurde in 2337_GL.png umbenannt.
# 2338.png wurde in 2338_GL.png umbenannt.
# 2339.png wurde in 2339_GL.png umbenannt.
# 2340.png wurde in 2340_GL.png umbenannt.
# 2341.png wurde in 2341_GL.png umbenannt.
# 2342.png wurde in 2342_GL.png umbenannt.
# 2343.png wurde in 2343_GL.png umbenannt.
# 2344.png wurde in 2344_GL.png umbenannt.
# 2345.png wurde in 2345_GL.png umbenannt.
# 2346.png wurde in 2346_GL.png umbenannt.
# 2347.png wurde in 2347_GL.png umbenannt.
# 2348.png wurde in 2348_GL.png umbenannt.
# 2349.png wurde in 2349_GL.png umbenannt.
# 2350.png wurde in 2350_GL.png umbenannt.
# 2351.png wurde in 2351_GL.png umbenannt.
# 2352.png wurde in 2352_GL.png umbenannt.
# 2353.png wurde in 2353_GL.png umbenannt.
# 2354.png wurde in 2354_GL.png umbenannt.
# 2355.png wurde in 2355_GL.png umbenannt.
# 2356.png wurde in 2356_GL.png umbenannt.
# 2357.png wurde in 2357_GL.png umbenannt.
# 2358.png wurde in 2358_GL.png umbenannt.
# 2359.png wurde in 2359_GL.png umbenannt.
# 2360.png wurde in 2360_GL.png umbenannt.
# 2361.png wurde in 2361_GL.png umbenannt.
# 2362.png wurde in 2362_GL.png umbenannt.
# 2363.png wurde in 2363_GL.png umbenannt.
# 2364.png wurde in 2364_GL.png umbenannt.
# 2365.png wurde in 2365_GL.png umbenannt.
# 2366.png wurde in 2366_GL.png umbenannt.
# 2367.png wurde in 2367_GL.png umbenannt.
# 2368.png wurde in 2368_GL.png umbenannt.
# 2369.png wurde in 2369_GL.png umbenannt.
# 2370.png wurde in 2370_GL.png umbenannt.
# 2371.png wurde in 2371_GL.png umbenannt.
# 2372.png wurde in 2372_GL.png umbenannt.
# 2373.png wurde in 2373_GL.png umbenannt.
# 2374.png wurde in 2374_GL.png umbenannt.
# 2375.png wurde in 2375_GL.png umbenannt.
# 2376.png wurde in 2376_GL.png umbenannt.
# 2377.png wurde in 2377_GL.png umbenannt.
# 2378.png wurde in 2378_GL.png umbenannt.
# 2379.png wurde in 2379_GL.png umbenannt.
# 2380.png wurde in 2380_GL.png umbenannt.
# 2381.png wurde in 2381_GL.png umbenannt.
# 2382.png wurde in 2382_GL.png umbenannt.
# 2383.png wurde in 2383_GL.png umbenannt.
# 2384.png wurde in 2384_GL.png umbenannt.
# 2385.png wurde in 2385_GL.png umbenannt.
# 2386.png wurde in 2386_GL.png umbenannt.
# 2387.png wurde in 2387_GL.png umbenannt.
# 2388.png wurde in 2388_GL.png umbenannt.
# 2389.png wurde in 2389_GL.png umbenannt.
# 2390.png wurde in 2390_GL.png umbenannt.
# 2391.png wurde in 2391_GL.png umbenannt.
# 2392.png wurde in 2392_GL.png umbenannt.
# 2393.png wurde in 2393_GL.png umbenannt.
# 2394.png wurde in 2394_GL.png umbenannt.
# 2395.png wurde in 2395_GL.png umbenannt.
# 2396.png wurde in 2396_GL.png umbenannt.
# 2397.png wurde in 2397_GL.png umbenannt.
# 2398.png wurde in 2398_GL.png umbenannt.
# 2399.png wurde in 2399_GL.png umbenannt.
# 2400.png wurde in 2400_GL.png umbenannt.
# 2401.png wurde in 2401_GL.png umbenannt.
# 2402.png wurde in 2402_GL.png umbenannt.
# 2403.png wurde in 2403_GL.png umbenannt.
# 2404.png wurde in 2404_GL.png umbenannt.
# 2405.png wurde in 2405_GL.png umbenannt.
# 2406.png wurde in 2406_GL.png umbenannt.
# 2407.png wurde in 2407_GL.png umbenannt.
# 2408.png wurde in 2408_GL.png umbenannt.
# 2409.png wurde in 2409_GL.png umbenannt.
# 2410.png wurde in 2410_GL.png umbenannt.
# 2411.png wurde in 2411_GL.png umbenannt.
# 2412.png wurde in 2412_GL.png umbenannt.
# 2413.png wurde in 2413_GL.png umbenannt.
# 2414.png wurde in 2414_GL.png umbenannt.
# 2415.png wurde in 2415_GL.png umbenannt.
# 2416.png wurde in 2416_GL.png umbenannt.
# 2417.png wurde in 2417_GL.png umbenannt.
# 2418.png wurde in 2418_GL.png umbenannt.
# 2419.png wurde in 2419_GL.png umbenannt.
# 2420.png wurde in 2420_GL.png umbenannt.
# 2421.png wurde in 2421_GL.png umbenannt.
# 2422.png wurde in 2422_GL.png umbenannt.
# 2423.png wurde in 2423_GL.png umbenannt.
# 2424.png wurde in 2424_GL.png umbenannt.
# 2425.png wurde in 2425_GL.png umbenannt.
# 2426.png wurde in 2426_GL.png umbenannt.
# 2427.png wurde in 2427_GL.png umbenannt.
# 2428.png wurde in 2428_GL.png umbenannt.
# 2429.png wurde in 2429_GL.png umbenannt.
# 2430.png wurde in 2430_GL.png umbenannt.
# 2431.png wurde in 2431_GL.png umbenannt.
# 2432.png wurde in 2432_GL.png umbenannt.
# 2433.png wurde in 2433_GL.png umbenannt.
# 2434.png wurde in 2434_GL.png umbenannt.
# 2435.png wurde in 2435_GL.png umbenannt.
# 2436.png wurde in 2436_GL.png umbenannt.
# 2437.png wurde in 2437_GL.png umbenannt.
# 2438.png wurde in 2438_GL.png umbenannt.
# 2439.png wurde in 2439_GL.png umbenannt.
# 2440.png wurde in 2440_GL.png umbenannt.
# 2441.png wurde in 2441_GL.png umbenannt.
# 2442.png wurde in 2442_GL.png umbenannt.
# 2443.png wurde in 2443_GL.png umbenannt.
# 2444.png wurde in 2444_GL.png umbenannt.
# 2445.png wurde in 2445_GL.png umbenannt.
# 2446.png wurde in 2446_GL.png umbenannt.
# 2447.png wurde in 2447_GL.png umbenannt.
# 2448.png wurde in 2448_GL.png umbenannt.
# 2449.png wurde in 2449_GL.png umbenannt.
# 2450.png wurde in 2450_GL.png umbenannt.
# 2451.png wurde in 2451_GL.png umbenannt.
# 2452.png wurde in 2452_GL.png umbenannt.
# 2453.png wurde in 2453_GL.png umbenannt.
# 2454.png wurde in 2454_GL.png umbenannt.
# 2455.png wurde in 2455_GL.png umbenannt.
# 2456.png wurde in 2456_GL.png umbenannt.
# 2457.png wurde in 2457_GL.png umbenannt.
# 2458.png wurde in 2458_GL.png umbenannt.
# 2459.png wurde in 2459_GL.png umbenannt.
# 2460.png wurde in 2460_GL.png umbenannt.
# 2461.png wurde in 2461_GL.png umbenannt.
# 2462.png wurde in 2462_GL.png umbenannt.
# 2463.png wurde in 2463_GL.png umbenannt.
# 2464.png wurde in 2464_GL.png umbenannt.
# 2465.png wurde in 2465_GL.png umbenannt.
# 2466.png wurde in 2466_GL.png umbenannt.
# 2467.png wurde in 2467_GL.png umbenannt.
# 2468.png wurde in 2468_GL.png umbenannt.
# 2469.png wurde in 2469_GL.png umbenannt.
# 2470.png wurde in 2470_GL.png umbenannt.
# 2471.png wurde in 2471_GL.png umbenannt.
# 2472.png wurde in 2472_GL.png umbenannt.
# 2473.png wurde in 2473_GL.png umbenannt.
# 2474.png wurde in 2474_GL.png umbenannt.
# 2475.png wurde in 2475_GL.png umbenannt.
# 2476.png wurde in 2476_GL.png umbenannt.
# 2477.png wurde in 2477_GL.png umbenannt.
# 2478.png wurde in 2478_GL.png umbenannt.
# 2479.png wurde in 2479_GL.png umbenannt.
# 2480.png wurde in 2480_GL.png umbenannt.
# 2481.png wurde in 2481_GL.png umbenannt.
# 2482.png wurde in 2482_GL.png umbenannt.
# 2483.png wurde in 2483_GL.png umbenannt.
# 2484.png wurde in 2484_GL.png umbenannt.
# 2485.png wurde in 2485_GL.png umbenannt.
# 2486.png wurde in 2486_GL.png umbenannt.
# 2487.png wurde in 2487_GL.png umbenannt.
# 2488.png wurde in 2488_GL.png umbenannt.
# 2489.png wurde in 2489_GL.png umbenannt.
# 2490.png wurde in 2490_GL.png umbenannt.
# 2491.png wurde in 2491_GL.png umbenannt.
# 2492.png wurde in 2492_GL.png umbenannt.
# 2493.png wurde in 2493_GL.png umbenannt.
# 2494.png wurde in 2494_GL.png umbenannt.
# 2495.png wurde in 2495_GL.png umbenannt.
# 2496.png wurde in 2496_GL.png umbenannt.
# 2497.png wurde in 2497_GL.png umbenannt.
# 2498.png wurde in 2498_GL.png umbenannt.
# 2499.png wurde in 2499_GL.png umbenannt.
# Labels werden umbenannt...
# 2000.txt wurde in 2000_GL.txt umbenannt.
# 2001.txt wurde in 2001_GL.txt umbenannt.
# 2002.txt wurde in 2002_GL.txt umbenannt.
# 2003.txt wurde in 2003_GL.txt umbenannt.
# 2004.txt wurde in 2004_GL.txt umbenannt.
# 2005.txt wurde in 2005_GL.txt umbenannt.
# 2006.txt wurde in 2006_GL.txt umbenannt.
# 2007.txt wurde in 2007_GL.txt umbenannt.
# 2008.txt wurde in 2008_GL.txt umbenannt.
# 2009.txt wurde in 2009_GL.txt umbenannt.
# 2010.txt wurde in 2010_GL.txt umbenannt.
# 2011.txt wurde in 2011_GL.txt umbenannt.
# 2012.txt wurde in 2012_GL.txt umbenannt.
# 2013.txt wurde in 2013_GL.txt umbenannt.
# 2014.txt wurde in 2014_GL.txt umbenannt.
# 2015.txt wurde in 2015_GL.txt umbenannt.
# 2016.txt wurde in 2016_GL.txt umbenannt.
# 2017.txt wurde in 2017_GL.txt umbenannt.
# 2018.txt wurde in 2018_GL.txt umbenannt.
# 2019.txt wurde in 2019_GL.txt umbenannt.
# 2020.txt wurde in 2020_GL.txt umbenannt.
# 2021.txt wurde in 2021_GL.txt umbenannt.
# 2022.txt wurde in 2022_GL.txt umbenannt.
# 2023.txt wurde in 2023_GL.txt umbenannt.
# 2024.txt wurde in 2024_GL.txt umbenannt.
# 2025.txt wurde in 2025_GL.txt umbenannt.
# 2026.txt wurde in 2026_GL.txt umbenannt.
# 2027.txt wurde in 2027_GL.txt umbenannt.
# 2028.txt wurde in 2028_GL.txt umbenannt.
# 2029.txt wurde in 2029_GL.txt umbenannt.
# 2030.txt wurde in 2030_GL.txt umbenannt.
# 2031.txt wurde in 2031_GL.txt umbenannt.
# 2032.txt wurde in 2032_GL.txt umbenannt.
# 2033.txt wurde in 2033_GL.txt umbenannt.
# 2034.txt wurde in 2034_GL.txt umbenannt.
# 2035.txt wurde in 2035_GL.txt umbenannt.
# 2036.txt wurde in 2036_GL.txt umbenannt.
# 2037.txt wurde in 2037_GL.txt umbenannt.
# 2038.txt wurde in 2038_GL.txt umbenannt.
# 2039.txt wurde in 2039_GL.txt umbenannt.
# 2040.txt wurde in 2040_GL.txt umbenannt.
# 2041.txt wurde in 2041_GL.txt umbenannt.
# 2042.txt wurde in 2042_GL.txt umbenannt.
# 2043.txt wurde in 2043_GL.txt umbenannt.
# 2044.txt wurde in 2044_GL.txt umbenannt.
# 2045.txt wurde in 2045_GL.txt umbenannt.
# 2046.txt wurde in 2046_GL.txt umbenannt.
# 2047.txt wurde in 2047_GL.txt umbenannt.
# 2048.txt wurde in 2048_GL.txt umbenannt.
# 2049.txt wurde in 2049_GL.txt umbenannt.
# 2050.txt wurde in 2050_GL.txt umbenannt.
# 2051.txt wurde in 2051_GL.txt umbenannt.
# 2052.txt wurde in 2052_GL.txt umbenannt.
# 2053.txt wurde in 2053_GL.txt umbenannt.
# 2054.txt wurde in 2054_GL.txt umbenannt.
# 2055.txt wurde in 2055_GL.txt umbenannt.
# 2056.txt wurde in 2056_GL.txt umbenannt.
# 2057.txt wurde in 2057_GL.txt umbenannt.
# 2058.txt wurde in 2058_GL.txt umbenannt.
# 2059.txt wurde in 2059_GL.txt umbenannt.
# 2060.txt wurde in 2060_GL.txt umbenannt.
# 2061.txt wurde in 2061_GL.txt umbenannt.
# 2062.txt wurde in 2062_GL.txt umbenannt.
# 2063.txt wurde in 2063_GL.txt umbenannt.
# 2064.txt wurde in 2064_GL.txt umbenannt.
# 2065.txt wurde in 2065_GL.txt umbenannt.
# 2066.txt wurde in 2066_GL.txt umbenannt.
# 2067.txt wurde in 2067_GL.txt umbenannt.
# 2068.txt wurde in 2068_GL.txt umbenannt.
# 2069.txt wurde in 2069_GL.txt umbenannt.
# 2070.txt wurde in 2070_GL.txt umbenannt.
# 2071.txt wurde in 2071_GL.txt umbenannt.
# 2072.txt wurde in 2072_GL.txt umbenannt.
# 2073.txt wurde in 2073_GL.txt umbenannt.
# 2074.txt wurde in 2074_GL.txt umbenannt.
# 2075.txt wurde in 2075_GL.txt umbenannt.
# 2076.txt wurde in 2076_GL.txt umbenannt.
# 2077.txt wurde in 2077_GL.txt umbenannt.
# 2078.txt wurde in 2078_GL.txt umbenannt.
# 2079.txt wurde in 2079_GL.txt umbenannt.
# 2080.txt wurde in 2080_GL.txt umbenannt.
# 2081.txt wurde in 2081_GL.txt umbenannt.
# 2082.txt wurde in 2082_GL.txt umbenannt.
# 2083.txt wurde in 2083_GL.txt umbenannt.
# 2084.txt wurde in 2084_GL.txt umbenannt.
# 2085.txt wurde in 2085_GL.txt umbenannt.
# 2086.txt wurde in 2086_GL.txt umbenannt.
# 2087.txt wurde in 2087_GL.txt umbenannt.
# 2088.txt wurde in 2088_GL.txt umbenannt.
# 2089.txt wurde in 2089_GL.txt umbenannt.
# 2090.txt wurde in 2090_GL.txt umbenannt.
# 2091.txt wurde in 2091_GL.txt umbenannt.
# 2092.txt wurde in 2092_GL.txt umbenannt.
# 2093.txt wurde in 2093_GL.txt umbenannt.
# 2094.txt wurde in 2094_GL.txt umbenannt.
# 2095.txt wurde in 2095_GL.txt umbenannt.
# 2096.txt wurde in 2096_GL.txt umbenannt.
# 2097.txt wurde in 2097_GL.txt umbenannt.
# 2098.txt wurde in 2098_GL.txt umbenannt.
# 2099.txt wurde in 2099_GL.txt umbenannt.
# 2100.txt wurde in 2100_GL.txt umbenannt.
# 2101.txt wurde in 2101_GL.txt umbenannt.
# 2102.txt wurde in 2102_GL.txt umbenannt.
# 2103.txt wurde in 2103_GL.txt umbenannt.
# 2104.txt wurde in 2104_GL.txt umbenannt.
# 2105.txt wurde in 2105_GL.txt umbenannt.
# 2106.txt wurde in 2106_GL.txt umbenannt.
# 2107.txt wurde in 2107_GL.txt umbenannt.
# 2108.txt wurde in 2108_GL.txt umbenannt.
# 2109.txt wurde in 2109_GL.txt umbenannt.
# 2110.txt wurde in 2110_GL.txt umbenannt.
# 2111.txt wurde in 2111_GL.txt umbenannt.
# 2112.txt wurde in 2112_GL.txt umbenannt.
# 2113.txt wurde in 2113_GL.txt umbenannt.
# 2114.txt wurde in 2114_GL.txt umbenannt.
# 2115.txt wurde in 2115_GL.txt umbenannt.
# 2116.txt wurde in 2116_GL.txt umbenannt.
# 2117.txt wurde in 2117_GL.txt umbenannt.
# 2118.txt wurde in 2118_GL.txt umbenannt.
# 2119.txt wurde in 2119_GL.txt umbenannt.
# 2120.txt wurde in 2120_GL.txt umbenannt.
# 2121.txt wurde in 2121_GL.txt umbenannt.
# 2122.txt wurde in 2122_GL.txt umbenannt.
# 2123.txt wurde in 2123_GL.txt umbenannt.
# 2124.txt wurde in 2124_GL.txt umbenannt.
# 2125.txt wurde in 2125_GL.txt umbenannt.
# 2126.txt wurde in 2126_GL.txt umbenannt.
# 2127.txt wurde in 2127_GL.txt umbenannt.
# 2128.txt wurde in 2128_GL.txt umbenannt.
# 2129.txt wurde in 2129_GL.txt umbenannt.
# 2130.txt wurde in 2130_GL.txt umbenannt.
# 2131.txt wurde in 2131_GL.txt umbenannt.
# 2132.txt wurde in 2132_GL.txt umbenannt.
# 2133.txt wurde in 2133_GL.txt umbenannt.
# 2134.txt wurde in 2134_GL.txt umbenannt.
# 2135.txt wurde in 2135_GL.txt umbenannt.
# 2136.txt wurde in 2136_GL.txt umbenannt.
# 2137.txt wurde in 2137_GL.txt umbenannt.
# 2138.txt wurde in 2138_GL.txt umbenannt.
# 2139.txt wurde in 2139_GL.txt umbenannt.
# 2140.txt wurde in 2140_GL.txt umbenannt.
# 2141.txt wurde in 2141_GL.txt umbenannt.
# 2142.txt wurde in 2142_GL.txt umbenannt.
# 2143.txt wurde in 2143_GL.txt umbenannt.
# 2144.txt wurde in 2144_GL.txt umbenannt.
# 2145.txt wurde in 2145_GL.txt umbenannt.
# 2146.txt wurde in 2146_GL.txt umbenannt.
# 2147.txt wurde in 2147_GL.txt umbenannt.
# 2148.txt wurde in 2148_GL.txt umbenannt.
# 2149.txt wurde in 2149_GL.txt umbenannt.
# 2150.txt wurde in 2150_GL.txt umbenannt.
# 2151.txt wurde in 2151_GL.txt umbenannt.
# 2152.txt wurde in 2152_GL.txt umbenannt.
# 2153.txt wurde in 2153_GL.txt umbenannt.
# 2154.txt wurde in 2154_GL.txt umbenannt.
# 2155.txt wurde in 2155_GL.txt umbenannt.
# 2156.txt wurde in 2156_GL.txt umbenannt.
# 2157.txt wurde in 2157_GL.txt umbenannt.
# 2158.txt wurde in 2158_GL.txt umbenannt.
# 2159.txt wurde in 2159_GL.txt umbenannt.
# 2160.txt wurde in 2160_GL.txt umbenannt.
# 2161.txt wurde in 2161_GL.txt umbenannt.
# 2162.txt wurde in 2162_GL.txt umbenannt.
# 2163.txt wurde in 2163_GL.txt umbenannt.
# 2164.txt wurde in 2164_GL.txt umbenannt.
# 2165.txt wurde in 2165_GL.txt umbenannt.
# 2166.txt wurde in 2166_GL.txt umbenannt.
# 2167.txt wurde in 2167_GL.txt umbenannt.
# 2168.txt wurde in 2168_GL.txt umbenannt.
# 2169.txt wurde in 2169_GL.txt umbenannt.
# 2170.txt wurde in 2170_GL.txt umbenannt.
# 2171.txt wurde in 2171_GL.txt umbenannt.
# 2172.txt wurde in 2172_GL.txt umbenannt.
# 2173.txt wurde in 2173_GL.txt umbenannt.
# 2174.txt wurde in 2174_GL.txt umbenannt.
# 2175.txt wurde in 2175_GL.txt umbenannt.
# 2176.txt wurde in 2176_GL.txt umbenannt.
# 2177.txt wurde in 2177_GL.txt umbenannt.
# 2178.txt wurde in 2178_GL.txt umbenannt.
# 2179.txt wurde in 2179_GL.txt umbenannt.
# 2180.txt wurde in 2180_GL.txt umbenannt.
# 2181.txt wurde in 2181_GL.txt umbenannt.
# 2182.txt wurde in 2182_GL.txt umbenannt.
# 2183.txt wurde in 2183_GL.txt umbenannt.
# 2184.txt wurde in 2184_GL.txt umbenannt.
# 2185.txt wurde in 2185_GL.txt umbenannt.
# 2186.txt wurde in 2186_GL.txt umbenannt.
# 2187.txt wurde in 2187_GL.txt umbenannt.
# 2188.txt wurde in 2188_GL.txt umbenannt.
# 2189.txt wurde in 2189_GL.txt umbenannt.
# 2190.txt wurde in 2190_GL.txt umbenannt.
# 2191.txt wurde in 2191_GL.txt umbenannt.
# 2192.txt wurde in 2192_GL.txt umbenannt.
# 2193.txt wurde in 2193_GL.txt umbenannt.
# 2194.txt wurde in 2194_GL.txt umbenannt.
# 2195.txt wurde in 2195_GL.txt umbenannt.
# 2196.txt wurde in 2196_GL.txt umbenannt.
# 2197.txt wurde in 2197_GL.txt umbenannt.
# 2198.txt wurde in 2198_GL.txt umbenannt.
# 2199.txt wurde in 2199_GL.txt umbenannt.
# 2200.txt wurde in 2200_GL.txt umbenannt.
# 2201.txt wurde in 2201_GL.txt umbenannt.
# 2202.txt wurde in 2202_GL.txt umbenannt.
# 2203.txt wurde in 2203_GL.txt umbenannt.
# 2204.txt wurde in 2204_GL.txt umbenannt.
# 2205.txt wurde in 2205_GL.txt umbenannt.
# 2206.txt wurde in 2206_GL.txt umbenannt.
# 2207.txt wurde in 2207_GL.txt umbenannt.
# 2208.txt wurde in 2208_GL.txt umbenannt.
# 2209.txt wurde in 2209_GL.txt umbenannt.
# 2210.txt wurde in 2210_GL.txt umbenannt.
# 2211.txt wurde in 2211_GL.txt umbenannt.
# 2212.txt wurde in 2212_GL.txt umbenannt.
# 2213.txt wurde in 2213_GL.txt umbenannt.
# 2214.txt wurde in 2214_GL.txt umbenannt.
# 2215.txt wurde in 2215_GL.txt umbenannt.
# 2216.txt wurde in 2216_GL.txt umbenannt.
# 2217.txt wurde in 2217_GL.txt umbenannt.
# 2218.txt wurde in 2218_GL.txt umbenannt.
# 2219.txt wurde in 2219_GL.txt umbenannt.
# 2220.txt wurde in 2220_GL.txt umbenannt.
# 2221.txt wurde in 2221_GL.txt umbenannt.
# 2222.txt wurde in 2222_GL.txt umbenannt.
# 2223.txt wurde in 2223_GL.txt umbenannt.
# 2224.txt wurde in 2224_GL.txt umbenannt.
# 2225.txt wurde in 2225_GL.txt umbenannt.
# 2226.txt wurde in 2226_GL.txt umbenannt.
# 2227.txt wurde in 2227_GL.txt umbenannt.
# 2228.txt wurde in 2228_GL.txt umbenannt.
# 2229.txt wurde in 2229_GL.txt umbenannt.
# 2230.txt wurde in 2230_GL.txt umbenannt.
# 2231.txt wurde in 2231_GL.txt umbenannt.
# 2232.txt wurde in 2232_GL.txt umbenannt.
# 2233.txt wurde in 2233_GL.txt umbenannt.
# 2234.txt wurde in 2234_GL.txt umbenannt.
# 2235.txt wurde in 2235_GL.txt umbenannt.
# 2236.txt wurde in 2236_GL.txt umbenannt.
# 2237.txt wurde in 2237_GL.txt umbenannt.
# 2238.txt wurde in 2238_GL.txt umbenannt.
# 2239.txt wurde in 2239_GL.txt umbenannt.
# 2240.txt wurde in 2240_GL.txt umbenannt.
# 2241.txt wurde in 2241_GL.txt umbenannt.
# 2242.txt wurde in 2242_GL.txt umbenannt.
# 2243.txt wurde in 2243_GL.txt umbenannt.
# 2244.txt wurde in 2244_GL.txt umbenannt.
# 2245.txt wurde in 2245_GL.txt umbenannt.
# 2246.txt wurde in 2246_GL.txt umbenannt.
# 2247.txt wurde in 2247_GL.txt umbenannt.
# 2248.txt wurde in 2248_GL.txt umbenannt.
# 2249.txt wurde in 2249_GL.txt umbenannt.
# 2250.txt wurde in 2250_GL.txt umbenannt.
# 2251.txt wurde in 2251_GL.txt umbenannt.
# 2252.txt wurde in 2252_GL.txt umbenannt.
# 2253.txt wurde in 2253_GL.txt umbenannt.
# 2254.txt wurde in 2254_GL.txt umbenannt.
# 2255.txt wurde in 2255_GL.txt umbenannt.
# 2256.txt wurde in 2256_GL.txt umbenannt.
# 2257.txt wurde in 2257_GL.txt umbenannt.
# 2258.txt wurde in 2258_GL.txt umbenannt.
# 2259.txt wurde in 2259_GL.txt umbenannt.
# 2260.txt wurde in 2260_GL.txt umbenannt.
# 2261.txt wurde in 2261_GL.txt umbenannt.
# 2262.txt wurde in 2262_GL.txt umbenannt.
# 2263.txt wurde in 2263_GL.txt umbenannt.
# 2264.txt wurde in 2264_GL.txt umbenannt.
# 2265.txt wurde in 2265_GL.txt umbenannt.
# 2266.txt wurde in 2266_GL.txt umbenannt.
# 2267.txt wurde in 2267_GL.txt umbenannt.
# 2268.txt wurde in 2268_GL.txt umbenannt.
# 2269.txt wurde in 2269_GL.txt umbenannt.
# 2270.txt wurde in 2270_GL.txt umbenannt.
# 2271.txt wurde in 2271_GL.txt umbenannt.
# 2272.txt wurde in 2272_GL.txt umbenannt.
# 2273.txt wurde in 2273_GL.txt umbenannt.
# 2274.txt wurde in 2274_GL.txt umbenannt.
# 2275.txt wurde in 2275_GL.txt umbenannt.
# 2276.txt wurde in 2276_GL.txt umbenannt.
# 2277.txt wurde in 2277_GL.txt umbenannt.
# 2278.txt wurde in 2278_GL.txt umbenannt.
# 2279.txt wurde in 2279_GL.txt umbenannt.
# 2280.txt wurde in 2280_GL.txt umbenannt.
# 2281.txt wurde in 2281_GL.txt umbenannt.
# 2282.txt wurde in 2282_GL.txt umbenannt.
# 2283.txt wurde in 2283_GL.txt umbenannt.
# 2284.txt wurde in 2284_GL.txt umbenannt.
# 2285.txt wurde in 2285_GL.txt umbenannt.
# 2286.txt wurde in 2286_GL.txt umbenannt.
# 2287.txt wurde in 2287_GL.txt umbenannt.
# 2288.txt wurde in 2288_GL.txt umbenannt.
# 2289.txt wurde in 2289_GL.txt umbenannt.
# 2290.txt wurde in 2290_GL.txt umbenannt.
# 2291.txt wurde in 2291_GL.txt umbenannt.
# 2292.txt wurde in 2292_GL.txt umbenannt.
# 2293.txt wurde in 2293_GL.txt umbenannt.
# 2294.txt wurde in 2294_GL.txt umbenannt.
# 2295.txt wurde in 2295_GL.txt umbenannt.
# 2296.txt wurde in 2296_GL.txt umbenannt.
# 2297.txt wurde in 2297_GL.txt umbenannt.
# 2298.txt wurde in 2298_GL.txt umbenannt.
# 2299.txt wurde in 2299_GL.txt umbenannt.
# 2300.txt wurde in 2300_GL.txt umbenannt.
# 2301.txt wurde in 2301_GL.txt umbenannt.
# 2302.txt wurde in 2302_GL.txt umbenannt.
# 2303.txt wurde in 2303_GL.txt umbenannt.
# 2304.txt wurde in 2304_GL.txt umbenannt.
# 2305.txt wurde in 2305_GL.txt umbenannt.
# 2306.txt wurde in 2306_GL.txt umbenannt.
# 2307.txt wurde in 2307_GL.txt umbenannt.
# 2308.txt wurde in 2308_GL.txt umbenannt.
# 2309.txt wurde in 2309_GL.txt umbenannt.
# 2310.txt wurde in 2310_GL.txt umbenannt.
# 2311.txt wurde in 2311_GL.txt umbenannt.
# 2312.txt wurde in 2312_GL.txt umbenannt.
# 2313.txt wurde in 2313_GL.txt umbenannt.
# 2314.txt wurde in 2314_GL.txt umbenannt.
# 2315.txt wurde in 2315_GL.txt umbenannt.
# 2316.txt wurde in 2316_GL.txt umbenannt.
# 2317.txt wurde in 2317_GL.txt umbenannt.
# 2318.txt wurde in 2318_GL.txt umbenannt.
# 2319.txt wurde in 2319_GL.txt umbenannt.
# 2320.txt wurde in 2320_GL.txt umbenannt.
# 2321.txt wurde in 2321_GL.txt umbenannt.
# 2322.txt wurde in 2322_GL.txt umbenannt.
# 2323.txt wurde in 2323_GL.txt umbenannt.
# 2324.txt wurde in 2324_GL.txt umbenannt.
# 2325.txt wurde in 2325_GL.txt umbenannt.
# 2326.txt wurde in 2326_GL.txt umbenannt.
# 2327.txt wurde in 2327_GL.txt umbenannt.
# 2328.txt wurde in 2328_GL.txt umbenannt.
# 2329.txt wurde in 2329_GL.txt umbenannt.
# 2330.txt wurde in 2330_GL.txt umbenannt.
# 2331.txt wurde in 2331_GL.txt umbenannt.
# 2332.txt wurde in 2332_GL.txt umbenannt.
# 2333.txt wurde in 2333_GL.txt umbenannt.
# 2334.txt wurde in 2334_GL.txt umbenannt.
# 2335.txt wurde in 2335_GL.txt umbenannt.
# 2336.txt wurde in 2336_GL.txt umbenannt.
# 2337.txt wurde in 2337_GL.txt umbenannt.
# 2338.txt wurde in 2338_GL.txt umbenannt.
# 2339.txt wurde in 2339_GL.txt umbenannt.
# 2340.txt wurde in 2340_GL.txt umbenannt.
# 2341.txt wurde in 2341_GL.txt umbenannt.
# 2342.txt wurde in 2342_GL.txt umbenannt.
# 2343.txt wurde in 2343_GL.txt umbenannt.
# 2344.txt wurde in 2344_GL.txt umbenannt.
# 2345.txt wurde in 2345_GL.txt umbenannt.
# 2346.txt wurde in 2346_GL.txt umbenannt.
# 2347.txt wurde in 2347_GL.txt umbenannt.
# 2348.txt wurde in 2348_GL.txt umbenannt.
# 2349.txt wurde in 2349_GL.txt umbenannt.
# 2350.txt wurde in 2350_GL.txt umbenannt.
# 2351.txt wurde in 2351_GL.txt umbenannt.
# 2352.txt wurde in 2352_GL.txt umbenannt.
# 2353.txt wurde in 2353_GL.txt umbenannt.
# 2354.txt wurde in 2354_GL.txt umbenannt.
# 2355.txt wurde in 2355_GL.txt umbenannt.
# 2356.txt wurde in 2356_GL.txt umbenannt.
# 2357.txt wurde in 2357_GL.txt umbenannt.
# 2358.txt wurde in 2358_GL.txt umbenannt.
# 2359.txt wurde in 2359_GL.txt umbenannt.
# 2360.txt wurde in 2360_GL.txt umbenannt.
# 2361.txt wurde in 2361_GL.txt umbenannt.
# 2362.txt wurde in 2362_GL.txt umbenannt.
# 2363.txt wurde in 2363_GL.txt umbenannt.
# 2364.txt wurde in 2364_GL.txt umbenannt.
# 2365.txt wurde in 2365_GL.txt umbenannt.
# 2366.txt wurde in 2366_GL.txt umbenannt.
# 2367.txt wurde in 2367_GL.txt umbenannt.
# 2368.txt wurde in 2368_GL.txt umbenannt.
# 2369.txt wurde in 2369_GL.txt umbenannt.
# 2370.txt wurde in 2370_GL.txt umbenannt.
# 2371.txt wurde in 2371_GL.txt umbenannt.
# 2372.txt wurde in 2372_GL.txt umbenannt.
# 2373.txt wurde in 2373_GL.txt umbenannt.
# 2374.txt wurde in 2374_GL.txt umbenannt.
# 2375.txt wurde in 2375_GL.txt umbenannt.
# 2376.txt wurde in 2376_GL.txt umbenannt.
# 2377.txt wurde in 2377_GL.txt umbenannt.
# 2378.txt wurde in 2378_GL.txt umbenannt.
# 2379.txt wurde in 2379_GL.txt umbenannt.
# 2380.txt wurde in 2380_GL.txt umbenannt.
# 2381.txt wurde in 2381_GL.txt umbenannt.
# 2382.txt wurde in 2382_GL.txt umbenannt.
# 2383.txt wurde in 2383_GL.txt umbenannt.
# 2384.txt wurde in 2384_GL.txt umbenannt.
# 2385.txt wurde in 2385_GL.txt umbenannt.
# 2386.txt wurde in 2386_GL.txt umbenannt.
# 2387.txt wurde in 2387_GL.txt umbenannt.
# 2388.txt wurde in 2388_GL.txt umbenannt.
# 2389.txt wurde in 2389_GL.txt umbenannt.
# 2390.txt wurde in 2390_GL.txt umbenannt.
# 2391.txt wurde in 2391_GL.txt umbenannt.
# 2392.txt wurde in 2392_GL.txt umbenannt.
# 2393.txt wurde in 2393_GL.txt umbenannt.
# 2394.txt wurde in 2394_GL.txt umbenannt.
# 2395.txt wurde in 2395_GL.txt umbenannt.
# 2396.txt wurde in 2396_GL.txt umbenannt.
# 2397.txt wurde in 2397_GL.txt umbenannt.
# 2398.txt wurde in 2398_GL.txt umbenannt.
# 2399.txt wurde in 2399_GL.txt umbenannt.
# 2400.txt wurde in 2400_GL.txt umbenannt.
# 2401.txt wurde in 2401_GL.txt umbenannt.
# 2402.txt wurde in 2402_GL.txt umbenannt.
# 2403.txt wurde in 2403_GL.txt umbenannt.
# 2404.txt wurde in 2404_GL.txt umbenannt.
# 2405.txt wurde in 2405_GL.txt umbenannt.
# 2406.txt wurde in 2406_GL.txt umbenannt.
# 2407.txt wurde in 2407_GL.txt umbenannt.
# 2408.txt wurde in 2408_GL.txt umbenannt.
# 2409.txt wurde in 2409_GL.txt umbenannt.
# 2410.txt wurde in 2410_GL.txt umbenannt.
# 2411.txt wurde in 2411_GL.txt umbenannt.
# 2412.txt wurde in 2412_GL.txt umbenannt.
# 2413.txt wurde in 2413_GL.txt umbenannt.
# 2414.txt wurde in 2414_GL.txt umbenannt.
# 2415.txt wurde in 2415_GL.txt umbenannt.
# 2416.txt wurde in 2416_GL.txt umbenannt.
# 2417.txt wurde in 2417_GL.txt umbenannt.
# 2418.txt wurde in 2418_GL.txt umbenannt.
# 2419.txt wurde in 2419_GL.txt umbenannt.
# 2420.txt wurde in 2420_GL.txt umbenannt.
# 2421.txt wurde in 2421_GL.txt umbenannt.
# 2422.txt wurde in 2422_GL.txt umbenannt.
# 2423.txt wurde in 2423_GL.txt umbenannt.
# 2424.txt wurde in 2424_GL.txt umbenannt.
# 2425.txt wurde in 2425_GL.txt umbenannt.
# 2426.txt wurde in 2426_GL.txt umbenannt.
# 2427.txt wurde in 2427_GL.txt umbenannt.
# 2428.txt wurde in 2428_GL.txt umbenannt.
# 2429.txt wurde in 2429_GL.txt umbenannt.
# 2430.txt wurde in 2430_GL.txt umbenannt.
# 2431.txt wurde in 2431_GL.txt umbenannt.
# 2432.txt wurde in 2432_GL.txt umbenannt.
# 2433.txt wurde in 2433_GL.txt umbenannt.
# 2434.txt wurde in 2434_GL.txt umbenannt.
# 2435.txt wurde in 2435_GL.txt umbenannt.
# 2436.txt wurde in 2436_GL.txt umbenannt.
# 2437.txt wurde in 2437_GL.txt umbenannt.
# 2438.txt wurde in 2438_GL.txt umbenannt.
# 2439.txt wurde in 2439_GL.txt umbenannt.
# 2440.txt wurde in 2440_GL.txt umbenannt.
# 2441.txt wurde in 2441_GL.txt umbenannt.
# 2442.txt wurde in 2442_GL.txt umbenannt.
# 2443.txt wurde in 2443_GL.txt umbenannt.
# 2444.txt wurde in 2444_GL.txt umbenannt.
# 2445.txt wurde in 2445_GL.txt umbenannt.
# 2446.txt wurde in 2446_GL.txt umbenannt.
# 2447.txt wurde in 2447_GL.txt umbenannt.
# 2448.txt wurde in 2448_GL.txt umbenannt.
# 2449.txt wurde in 2449_GL.txt umbenannt.
# 2450.txt wurde in 2450_GL.txt umbenannt.
# 2451.txt wurde in 2451_GL.txt umbenannt.
# 2452.txt wurde in 2452_GL.txt umbenannt.
# 2453.txt wurde in 2453_GL.txt umbenannt.
# 2454.txt wurde in 2454_GL.txt umbenannt.
# 2455.txt wurde in 2455_GL.txt umbenannt.
# 2456.txt wurde in 2456_GL.txt umbenannt.
# 2457.txt wurde in 2457_GL.txt umbenannt.
# 2458.txt wurde in 2458_GL.txt umbenannt.
# 2459.txt wurde in 2459_GL.txt umbenannt.
# 2460.txt wurde in 2460_GL.txt umbenannt.
# 2461.txt wurde in 2461_GL.txt umbenannt.
# 2462.txt wurde in 2462_GL.txt umbenannt.
# 2463.txt wurde in 2463_GL.txt umbenannt.
# 2464.txt wurde in 2464_GL.txt umbenannt.
# 2465.txt wurde in 2465_GL.txt umbenannt.
# 2466.txt wurde in 2466_GL.txt umbenannt.
# 2467.txt wurde in 2467_GL.txt umbenannt.
# 2468.txt wurde in 2468_GL.txt umbenannt.
# 2469.txt wurde in 2469_GL.txt umbenannt.
# 2470.txt wurde in 2470_GL.txt umbenannt.
# 2471.txt wurde in 2471_GL.txt umbenannt.
# 2472.txt wurde in 2472_GL.txt umbenannt.
# 2473.txt wurde in 2473_GL.txt umbenannt.
# 2474.txt wurde in 2474_GL.txt umbenannt.
# 2475.txt wurde in 2475_GL.txt umbenannt.
# 2476.txt wurde in 2476_GL.txt umbenannt.
# 2477.txt wurde in 2477_GL.txt umbenannt.
# 2478.txt wurde in 2478_GL.txt umbenannt.
# 2479.txt wurde in 2479_GL.txt umbenannt.
# 2480.txt wurde in 2480_GL.txt umbenannt.
# 2481.txt wurde in 2481_GL.txt umbenannt.
# 2482.txt wurde in 2482_GL.txt umbenannt.
# 2483.txt wurde in 2483_GL.txt umbenannt.
# 2484.txt wurde in 2484_GL.txt umbenannt.
# 2485.txt wurde in 2485_GL.txt umbenannt.
# 2486.txt wurde in 2486_GL.txt umbenannt.
# 2487.txt wurde in 2487_GL.txt umbenannt.
# 2488.txt wurde in 2488_GL.txt umbenannt.
# 2489.txt wurde in 2489_GL.txt umbenannt.
# 2490.txt wurde in 2490_GL.txt umbenannt.
# 2491.txt wurde in 2491_GL.txt umbenannt.
# 2492.txt wurde in 2492_GL.txt umbenannt.
# 2493.txt wurde in 2493_GL.txt umbenannt.
# 2494.txt wurde in 2494_GL.txt umbenannt.
# 2495.txt wurde in 2495_GL.txt umbenannt.
# 2496.txt wurde in 2496_GL.txt umbenannt.
# 2497.txt wurde in 2497_GL.txt umbenannt.
# 2498.txt wurde in 2498_GL.txt umbenannt.
# 2499.txt wurde in 2499_GL.txt umbenannt.
# Umbenennen abgeschlossen.

# %%
import os

# Pfad zum Ordner mit den Bildern
folder_path = r"C:\Uni\python\Bachalor_Arbeit_Pthon\test\Hintergrund"

def rename_images_in_folder(folder_path):
    try:
        # Liste aller Dateien im Ordner
        files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
        
        # Nur Bilddateien auswählen (z. B. .png, .jpg)
        image_files = [f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        # Dateien umbenennen
        for index, file_name in enumerate(image_files):
            # Neuer Name
            new_name = f"Hintergrund_{index}.jpg"
            
            # Alter und neuer vollständiger Pfad
            old_path = os.path.join(folder_path, file_name)
            new_path = os.path.join(folder_path, new_name)
            
            # Datei umbenennen
            os.rename(old_path, new_path)
            print(f"Renamed: {file_name} -> {new_name}")
            
        print("Alle Bilder wurden erfolgreich umbenannt!")
    
    except Exception as e:
        print(f"Ein Fehler ist aufgetreten: {e}")

# Funktion aufrufen
rename_images_in_folder(folder_path)
# Out:
# Renamed: An-2JCa3WNVqameKxkrvcR8LUhuItcICBla_y1e1sv_zbfBRkWjoUYbtXLx1Qjy99iRAP1F5D0fjN-VNLaRVFWzRFjvbkKQ0TA5Ja_bk-i2N3-XdiRuusTEvPQm-DusDxGU5MNuHvZ-oUoTctETTXA0.jpg -> Hintergrund_0.jpg
# Renamed: An-3dFAdAgvuMtqQce1k4HNnzgve3YvqIujsfyUmYi9lbIXnaAbgedtbNzofu7KvQ48aEnNkUZBFaC6VSmv7HrU9306gBaUoOiZvcyB_6y9NuG2HSzPUUA1yBZgGPnHgrg7LVF3JjHyYqebgcyvvONw.jpg -> Hintergrund_1.jpg
# Renamed: An-gpuRK6u8XMvLHi56-Ymc-l0gAtxFtdRHJ8r2C0XN8H_jH-6U6COAJ-OEmzdyT3x5SjVQwEAJlkK00tjyMgbIIb_ktZZhFShEtm39NGhAu-ya2FPop3F5ZE-CmfdudwDpu_PsfogkOu9BBqKDKJw.jpg -> Hintergrund_2.jpg
# Renamed: An-Jy0UfjuNgrt5Izps76DpxiLIFcwCdMCah7I_CipDL83QwIYGTyWFPdkgQp4LRz0Uxx8cP_IeTuOJ2wFW8b99z2UzRxXTTpFy-iHxYEhm20SgCPJ1pp-hNSCkRuIC4VTeGXcJuIiCc3pa5dUQqvw.jpg -> Hintergrund_3.jpg
# Renamed: An-NirtybdMecNKH9ixY4oHdFHkjxWVFzh11dqipyEzKNQK9sZqSW_HAc6QeZWs1usC0KW3UVpem59ouHYnxMXjRJndfSD-XIkCzzmReqrof3_lR-7Ma1lMEm58XI5JLsUPCSN08tilINE5pFQsisg.jpg -> Hintergrund_4.jpg
# Renamed: An-riHYP21MCEB-Huo_eSZfvYCGwuzhcwdYW7fs5cnNzb3y-757UamjSsB1iyPbuDa0OFYWz8Z9sub9oS7GJ42oeJJjdvCJn4Jl9u95y26kgZP3S64SGTCizr1BR3AIBaJQLY_hwke0uS5Mbf8AbVg.jpg -> Hintergrund_5.jpg
# Renamed: An-UsW5FVO8VVK_s1DYrNh-sgyznx_kSTJYB2nB4mg9jBjEsorvZiucp-XECv7DY0nI9Pnl11lMxakUe5fZHOltG_hDctpBhuszjs8eXJvfYZXZ-BVGOZ1t-Yy82pvK5EdeP5RY6R_CVHZQZIrJNNv4.jpg -> Hintergrund_6.jpg
# Renamed: An81QGhAzCjsj-Fy-OAetVQczgqtcPVQq_vPjdKu--yryc23WET0DgQrUCfJkBkqRgZFrZxSxngJ5ybI9NMvl7TaGWKt09ECYVC5Xm7T9BwdqQ2NJaUTbfwZKIzp25UTkNzl2putS8NxRgZbVrbB7A.jpg -> Hintergrund_7.jpg
# Renamed: An8a_xXy_cpF6xXsu1jN0zd2zUZ8r4EYvtXls-VZ5Z8dIMBq16eZ4m-R9MeOLjvq1awJGYEWON36HHRMYl-hcTgJHo1wKRzYTN89cLVOB54G7LqlWTGHBEJCJly5Jc2uizVPgFjbpBB_jhCOJsbZOg.jpg -> Hintergrund_8.jpg
# Renamed: An8Egf7HdBb_PWZ8ova4VxOHyfESwj9dpoevWiUXep9N7Y2cOljDBT10jwungSh6q4Bn-Mqc3N_cxgmAm63z88YIzkedOhvgawRxSEyWF3G6FzejImAbiahsL4FaRNi8HrG3Http4RFpgeLFdUnkiQ.jpg -> Hintergrund_9.jpg
# Renamed: An8F4-60US4tOGAN_dp3EOmjVxz3MZNoinQS_qI74mndXM1q7OtcLH0pT3-gmLyMz_i49G2ub8jc5IvzkDUkKG13NJPZt4NaMcVW0SvvL1t1Yma0zdwLZ_ehlNiocxo1eQQbEMxnt8cVFbdNj9bMOA.jpg -> Hintergrund_10.jpg
# Renamed: An8HQ-tV__iB-JHo7FD3Hg-x0C5WmnUiG0NCznrN_Z_QcNebDmxR4vaDdFLWPlD2Sapd7LDvCipS3hKmAofkchCtTPqqTNEj4HvKvPpzl_BK5h6dFP8qF5o6epg43p4o09RE3DJ9HTknRfzJn3zk1A.jpg -> Hintergrund_11.jpg
# Renamed: An8MJjzXVFtdOTiOxL3M2wfxjPk1ae3VGMZcb2XQMmr885-4tGRBHPMvdbTZVMe4CFczjI71ozOczbXoMZQq8hpTfBR5sZ2a6UgIUAhbjN727oYlqnobFetsSU-RkxwE37UKhf6IbYB3lYmhWieSKw.jpg -> Hintergrund_12.jpg
# Renamed: An8sMlftKpsFXLUaP0Lc-I027fZ6uw3RF29WpJ9R-5MBMnCK99M9ZuY74fVuQ3qjabFhpaeBAdI3CHSGgrAYffEX2E6zCBsSqrON5Jf6-cQkAfy7DwKLeAvykRp_y_BFlzUQC73karX4RHjRUac-e-8.jpg -> Hintergrund_13.jpg
# Renamed: An8UiEtNZjgVrq_1lXnwI2Broz-WiWQ0lq0Rq-a7OMgVbhqF5hI4DsdnZRMt4wviaPG-P7PPBehh1L2uPzychTguG69M6FRe26g7cTTPW-i7ycsoqKPtAbiAKy4OTwnJJuFQSql7o3oqErUT7xdLdA.jpg -> Hintergrund_14.jpg
# Renamed: An8x7WqFERh5q08SJfEeohgpuhAffx4oWm6xf1r2LX2j9zB-fikieeo0exF-rLFtgubyRWJSWmaPNL2TSliDps730IczHcZNxZ3ZoxMlun6msDE2AMaHVK1ht0-marfALWALRVTFPnmhiY801nS3wg.jpg -> Hintergrund_15.jpg
# Renamed: An8YMufP-6WcuUpzSWx4a9khKmLm2qp6Y53hOnxsEl0vhgh_XOm6wxu0olHshZdtH0v5VgFUGRKxEeU8qYyAnf3vCzjQ_vRx2i5gaUtn9f1V2Jz-rnqy-Vq7GJXyfp4HCDIwuuPAIj49sl3QTF8di5c.jpg -> Hintergrund_16.jpg
# Renamed: An91kL5LeMzaYtNSMZkiESFAVt5wX1gZs9Qq_vOaS6ETEaMXu25oJxZMBqzJD-Q3qvk23ldBMq9iHaXRoOmJ12Ktp72QBUDanpr6vSUBgsKWYf3LrKep2rPaO8eTyueJ28nJ_1s6H6XKYT5K2LsAiw.jpg -> Hintergrund_17.jpg
# Renamed: An95hcKrDPr_8CgAEFpHG9J7yNXm3xLOKFIi7bnGBmcWnHVSrbpcUVmixs03rIOS-RCnotw8BLQQEtfEzlgZs6AkFtWPaN1uTxi3woFsgoLP-vKJ8z3PqfKXFmb1jPpD128nJvASJOB8RrMk7HCzJA.jpg -> Hintergrund_18.jpg
# Renamed: An9AhN75zghxdmTpdg2Zf3gWKEEbYzpHmMSYeS2CuMegD7JjJ_1bAKT8iPVe7Bh9qN4t4o02DasMxJzFSqwifST8sBK0fPPg5Kwl0TrypbQmmDfrgF6cwA1BdO5L4QfpVEc9Sau6tyM7YiKpRTAw1A.jpg -> Hintergrund_19.jpg
# Renamed: An9cT0ihvQyeylWTR2QZ7vPPx2NgegTwbDgGQwS9XwwuByPsYyr4XEHIL9Wbo_rbOD7ZmdWqd7s5F1zfXENc5rOVnYAeIgpDc502uKtJzDZF_DzT4X3ifjoGqC1laDSP7itLyUgelYze_NHpRwu_wOI.jpg -> Hintergrund_20.jpg
# Renamed: An9GCqelOD9l5MGq3JdmMK9nIDpGoxskgrW43tm3rySjs6VkBBqD8DlCuv7S4NyMsY5AuSIvqF--qvS_T24qUkUra6Kk3LAOcL2DLup1UxTcwloh0mMNpstKkwa2UWqqSyo_4CR9eu1BgYLdaW6eOg.jpg -> Hintergrund_21.jpg
# Renamed: An9lzWOkL7E1Rx_VolxZxri47jvqFufYdLAJkUa6HFByuzl0_yb3SI86FvxGbB9Vvc7BoxcTSPuyKfw_B-BsMCc5HK6lyMWwBDt0MaUlUM2JhNaFT1Co6ldvwqvMdVzGVYkZq5bcSzA0YnI4YZhNUQ.jpg -> Hintergrund_22.jpg
# Renamed: An9MW5u4qQGEqRC9ferdL-gZzUdpXrNJXWNuRwPv-s_IwH66eHsS72KpGlbDYAd8lexAZFkSgIa5qtZOLDDsNkAbwElOx_a4m42skDJ0Mtblbmlsq8WmSsjM5SHcwPGbkf9B_mxA6t1pbsYfUPLToE8.jpg -> Hintergrund_23.jpg
# Renamed: An9NH7ByyZU50MQN2hGlK6Vmelo9vJjLgVJj3xlXwe9Jh-d6xrhpllPjF0gTY4yG_751cZXrDrDSM_wg--xPJqH8EhmSCh_-Rj2uiCE7MRiEJQ9Fh4N2EIa3BsS9jN9mqN_HmG22S3WYPAJrDWZUAA.jpg -> Hintergrund_24.jpg
# Renamed: An9r-ya9XkGFk5al8d-tM_Qee1GHqSeuOsL5PKoFUxIwQ8ktAddzhnelamCxKAm5MkyZojsjE0KIJU3jErMijnf2jiOnSAIWU3Dk1kQWJyJII541R0qzUYp8Al2DbRkJL7eVHACTprpgb4Xn17puuC8.jpg -> Hintergrund_25.jpg
# Renamed: An9rFHm4Gq-XSkOQvgD76KdOnkGYqOLoatkww2eZl19TNSkJdSZPId5ZRId3GY2Ss4SihOCTTrGyTEjY8p_PoXkGeSXQZRz4FfCces0zoHDu2Sr3Zr2yCbKAGX0lL0b8XCVhJZpQ0uWBdqPtdqWNjg.jpg -> Hintergrund_26.jpg
# Renamed: An9RGwQcWuZmRAiJTRnGmi5Xj_xaB2afDT9JQ5MRgoSQqWkU2fIZDmBvkME-gBhMKY0ixncnaOXgKjc30Pl9nxATf_AtdLcxpHsqA9V7CXYuhhF6sUdUr6kw1EKj5svcDyt0Crv25cLULxO5Dplb2Q.jpg -> Hintergrund_27.jpg
# Renamed: An9Svz8ldIpPadWH_LSjEebQ9KdogOy1mqGl9TaCq-ugi8wGCpx69gpz1fNMptxifYFeZ6mJF_MQdFG-17deoshTbxJlE0DlJiUKlAevBbaH7eT-advzqnknH7FdrqEUGk6XRQHoym_gbTsN1gdYBA.jpg -> Hintergrund_28.jpg
# Renamed: An9T4uf9vn0fIWvNvwGFEdtQnKrTDRncZwknpT5JxhDC0SfBsdUkJqgQcxLgbGdo-8ETqdeaA76WfI8RNXySKmuJnzVjL8yQ9MV0Hrq0BG2RDVbmF1QG3YzrvCV1xuo-pycm3-nFWOOW-D6QciOSMA.jpg -> Hintergrund_29.jpg
# Renamed: An_H557XcEHjyRiP16t9VrjTBDrsF0NLIruRiWPErT0J4FrOPr0yqBwmyzrb19DvvOqFqvx6p0J7AM7qn_oertoqFd-UuTSXj7g-z4g3owG6fTMgk7pReuiNMKC7A0JDmE0lYqX6lq_3qFVQq7AtJA.jpg -> Hintergrund_30.jpg
# Renamed: An_QUSikmvA6QjgQgTP2EEA1PuvMGDNPQhnui2B2zLTkuze2kWwU7AGjugu0IGN6Z6VQrCEyEX8g2wEWI_j6TX_RsXjzaTP74oF52onIKln-WoUnzlrfH7IK_k2dfBhElnOH9LCuUFsfLsMcpRly-w.jpg -> Hintergrund_31.jpg
# Renamed: An_V4mJjOGw3Fh-2xt-souln0UoNAm_hI2UJuCLgOxqFojr3qqgIRHEQ20g5ux6GVbk6_BF5V_ohl07YSQ-bcMUtJ0NjCnOiane8kppgXp-8S-2wJlYkFi6NIc-KlSncycxjjcdkpyBa2n6gCLafhA.jpg -> Hintergrund_32.jpg
# Renamed: An_vzchmOpoKsGWnpUCKODJE-v0PGb5nF6w0HaRvwRnBNpLkL3JW4f4PbdHvjwYsZ0OZsrKYGUxHkdv-UVOMXltqK8jy8xcAtfupooclXe6sJbdSnzr6wqyIYg_zkSJgFtI8b1kk7sv17AOucrP9vg.jpg -> Hintergrund_33.jpg
# Renamed: An_XBYkADjKp5G9FF-GBAdnOzge_27clP8c8DDt3tbULSDeoR3tsMRk56sh1rdOENBd2ln90PVYtPTkiCzEQQs0ksxnMjOUcYr0TjvKx7VVQC6hJLwCJCfmsh81MmvBpPTrv_kAQ6dukFdOlM2h76Q.jpg -> Hintergrund_34.jpg
# Renamed: An_Xz36lbT2BnA_A972lB8fOb3Ut5Jqs_hBe67jFVU6AGIh2hBqY5zyIfDH_JHl2B_sTDsUgz58FIKskSJgRRDaqF8i70z2LL8BuMjTo-bOg4VUkC0tfQPSv41XLfH0MIbBTPb2HmzIdlebYxfGObg.jpg -> Hintergrund_35.jpg
# Renamed: An_yEqM_PmSX9syV918G3Qrk-s5wiidKF3Qo2F90cqjYP8kv-zNydu6XaQwPetsNtQGi7J6X_OvKAv9K2O0y-WORMMekoEtJSCdSm5P2X30I_59O2hSFmILYLa_d6SMqR2eC7wzvYG-WC4prpc0AVQ.jpg -> Hintergrund_36.jpg
# Renamed: An_YTvhjRbC-A9HnLnoDjY4TYeDyiEUHmilhMp9s7miGciehkPhqfwn5vD3_vNNUYo-J6LalhFOMta09LY1g2GFgb1-9oH6aUXcW9MjAaJKUVHcs9En4eXWn3GTtDd4ofI-QjVJf_Sct7IHEM-3_mO8.jpg -> Hintergrund_37.jpg
# Alle Bilder wurden erfolgreich umbenannt!

# %%
import os
import cv2
import numpy as np
from random import choice, randint
from PIL import Image

# Pfade definieren
fraunhofer_paths = {
    0: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\33_VorgeschriebeneFahrtrichtungRechts",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\33_VorgeschriebeneFahrtrichtungRechts"},
    1: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\34_VorgeschriebeneFahrtrichtungLinks",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\34_VorgeschriebeneFahrtrichtungLinks"},
    2: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\36_VorgeschriebeneFahrtrichtungGeradeausOderRechts",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\36_VorgeschriebeneFahrtrichtungGeradeausOderRechts"},
    3: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\37_VorgeschriebeneFahrtrichtungGeradeausOderLinks",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\37_VorgeschriebeneFahrtrichtungGeradeausOderLinks"}
}

background_path = r"C:\Uni\python\data\Bilder_mibilirty\UNI"
output_path = r"C:\Uni\python\output"  # Ordner für generierte Bilder und Labels
output_images_path = os.path.join(output_path, "Images")
output_labels_path = os.path.join(output_path, "Labels")

# Ordner erstellen
os.makedirs(output_images_path, exist_ok=True)
os.makedirs(output_labels_path, exist_ok=True)

# Funktion zur Erstellung von synthetischen Bildern
def create_synthetic_images(fraunhofer_class, num_images):
    img_folder = fraunhofer_paths[fraunhofer_class]["images"]
    mask_folder = fraunhofer_paths[fraunhofer_class]["masks"]

    image_files = os.listdir(img_folder)
    mask_files = os.listdir(mask_folder)
    background_files = os.listdir(background_path)

    for i in range(num_images):
        # Zufällige Auswahl von Bild, Maske und Hintergrund
        img_file = choice(image_files)
        mask_file = choice(mask_files)
        bg_file = choice(background_files)

        # Lade die Bilder
        img = cv2.imread(os.path.join(img_folder, img_file), cv2.IMREAD_UNCHANGED)
        mask = cv2.imread(os.path.join(mask_folder, mask_file), cv2.IMREAD_GRAYSCALE)
        bg = cv2.imread(os.path.join(background_path, bg_file))

        # Überprüfe Dimensionen
        if img is None or mask is None or bg is None:
            continue

        # Hintergrundgröße anpassen
        bg = cv2.resize(bg, (640, 480))

        # Zufällige Skalierung und Platzierung
        scale_factor = randint(50, 100) / 100
        img = cv2.resize(img, (int(img.shape[1] * scale_factor), int(img.shape[0] * scale_factor)))
        mask = cv2.resize(mask, (img.shape[1], img.shape[0]))

        # Verhindern, dass das Verkehrszeichen größer als der Hintergrund ist
        if img.shape[0] > bg.shape[0] or img.shape[1] > bg.shape[1]:
            scale_factor = min(bg.shape[0] / img.shape[0], bg.shape[1] / img.shape[1]) * 0.8
            img = cv2.resize(img, (int(img.shape[1] * scale_factor), int(img.shape[0] * scale_factor)))
            mask = cv2.resize(mask, (img.shape[1], img.shape[0]))

        # Zufällige Positionierung
        x_offset = randint(0, bg.shape[1] - img.shape[1])
        y_offset = randint(0, bg.shape[0] - img.shape[0])

        # Maske anwenden
        roi = bg[y_offset:y_offset+img.shape[0], x_offset:x_offset+img.shape[1]]
        roi[np.where(mask != 0)] = img[np.where(mask != 0)]

        # Hintergrund aktualisieren
        bg[y_offset:y_offset+img.shape[0], x_offset:x_offset+img.shape[1]] = roi

        # YOLO-Label generieren
        x_center = (x_offset + img.shape[1] / 2) / bg.shape[1]
        y_center = (y_offset + img.shape[0] / 2) / bg.shape[0]
        width = img.shape[1] / bg.shape[1]
        height = img.shape[0] / bg.shape[0]

        label = f"{fraunhofer_class} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n"

        # Speichern
        image_name = f"{fraunhofer_class}_{i}.jpg"
        label_name = f"{fraunhofer_class}_{i}.txt"

        cv2.imwrite(os.path.join(output_images_path, image_name), bg)
        with open(os.path.join(output_labels_path, label_name), "w") as label_file:
            label_file.write(label)

# Für jede Klasse Bilder generieren
for class_id in fraunhofer_paths.keys():
    create_synthetic_images(class_id, 75)  # 76 Bilder pro Klasse erstellen

# %%
import os
import cv2
import numpy as np
from random import choice, randint, sample

# Pfade definieren
fraunhofer_paths = {
    0: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\33_VorgeschriebeneFahrtrichtungRechts",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\33_VorgeschriebeneFahrtrichtungRechts"},
    1: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\34_VorgeschriebeneFahrtrichtungLinks",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\34_VorgeschriebeneFahrtrichtungLinks"},
    2: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\36_VorgeschriebeneFahrtrichtungGeradeausOderRechts",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\36_VorgeschriebeneFahrtrichtungGeradeausOderRechts"},
    3: {"images": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\37_VorgeschriebeneFahrtrichtungGeradeausOderLinks",
        "masks": r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\37_VorgeschriebeneFahrtrichtungGeradeausOderLinks"}
}

background_path = r"C:\Uni\python\data\Bilder_mibilirty\UNI"
output_path = r"C:\Uni\python\output"  # Ordner für generierte Bilder und Labels
output_images_path = os.path.join(output_path, "Images")
output_labels_path = os.path.join(output_path, "Labels")

# Ordner erstellen
os.makedirs(output_images_path, exist_ok=True)
os.makedirs(output_labels_path, exist_ok=True)

# Funktion zur zufälligen Auswahl von Verkehrszeichen und zugehörigen Masken
def load_random_sign(class_id):
    img_folder = fraunhofer_paths[class_id]["images"]
    mask_folder = fraunhofer_paths[class_id]["masks"]

    valid_extensions = (".png", ".jpg", ".jpeg")
    image_files = [f for f in os.listdir(img_folder) if f.endswith(valid_extensions)]
    mask_files = [f for f in os.listdir(mask_folder) if f.endswith(valid_extensions)]

    matched_files = [f for f in image_files if f.replace("cycles", "msk") in mask_files]

    if not matched_files:
        raise FileNotFoundError(f"Keine passenden Masken für Klasse {class_id} gefunden.")

    image_file = choice(matched_files)
    mask_file = image_file.replace("cycles", "msk")

    img = cv2.imread(os.path.join(img_folder, image_file), cv2.IMREAD_UNCHANGED)
    mask = cv2.imread(os.path.join(mask_folder, mask_file), cv2.IMREAD_GRAYSCALE)

    if img is None or mask is None:
        raise FileNotFoundError(f"Fehler beim Laden von: {image_file} oder {mask_file}")

    return img, mask

# Funktion zur Überprüfung der Überlappung
def is_overlapping(x, y, w, h, used_areas):
    for ux, uy, uw, uh in used_areas:
        if not (x + w <= ux or ux + uw <= x or y + h <= uy or uy + uh <= y):
            return True
    return False

# Funktion zur Erstellung eines Bildes mit mehreren Verkehrszeichen
def create_composite_image(background, class_ids):
    height, width, _ = background.shape
    labels = []
    used_areas = []

    for class_id in class_ids:
        try:
            img, mask = load_random_sign(class_id)

            scale_factor = randint(50, 100) / 100
            img = cv2.resize(img, (int(img.shape[1] * scale_factor), int(img.shape[0] * scale_factor)))
            mask = cv2.resize(mask, (img.shape[1], img.shape[0]))

            # Maske verwenden, um exakte Objektgrenzen zu finden
            coords = cv2.findNonZero(mask)
            x_min, y_min, w, h = cv2.boundingRect(coords)

            for _ in range(10):  # Maximal 10 Versuche
                x_offset = randint(0, width - w)
                y_offset = randint(0, height - h)

                if not is_overlapping(x_offset, y_offset, w, h, used_areas):
                    break
            else:
                continue  # Überspringe, wenn keine gültige Position gefunden wird

            # Bereich im Hintergrund anpassen
            x_end = min(x_offset + w, width)
            y_end = min(y_offset + h, height)
            img_cropped = img[y_min:y_min + (y_end - y_offset), x_min:x_min + (x_end - x_offset)]
            mask_cropped = mask[y_min:y_min + (y_end - y_offset), x_min:x_min + (x_end - x_offset)]

            roi = background[y_offset:y_end, x_offset:x_end]
            roi[mask_cropped != 0] = img_cropped[mask_cropped != 0]
            background[y_offset:y_end, x_offset:x_end] = roi

            x_center = (x_offset + w / 2) / width
            y_center = (y_offset + h / 2) / height
            bbox_width = w / width
            bbox_height = h / height

            labels.append(f"{class_id} {x_center:.6f} {y_center:.6f} {bbox_width:.6f} {bbox_height:.6f}")
            used_areas.append((x_offset, y_offset, w, h))
        except FileNotFoundError as e:
            print(e)
            continue

    return background, labels

# Hauptfunktion zur Generierung von Bildern
def generate_images():
    background_files = os.listdir(background_path)

    for class_id in fraunhofer_paths.keys():
        for i in range(30):
            bg_file = choice(background_files)
            background = cv2.imread(os.path.join(background_path, bg_file))
            background = cv2.resize(background, (640, 480))

            composite_image, labels = create_composite_image(background, [class_id])

            image_name = f"class_{class_id}_single_{i}.jpg"
            label_name = f"class_{class_id}_single_{i}.txt"

            cv2.imwrite(os.path.join(output_images_path, image_name), composite_image)
            with open(os.path.join(output_labels_path, label_name), "w") as label_file:
                label_file.write("\n".join(labels))

        for i in range(20):
            bg_file = choice(background_files)
            background = cv2.imread(os.path.join(background_path, bg_file))
            background = cv2.resize(background, (640, 480))

            other_class = choice([c for c in fraunhofer_paths.keys() if c != class_id])
            composite_image, labels = create_composite_image(background, [class_id, other_class])

            image_name = f"class_{class_id}_pair_{i}.jpg"
            label_name = f"class_{class_id}_pair_{i}.txt"

            cv2.imwrite(os.path.join(output_images_path, image_name), composite_image)
            with open(os.path.join(output_labels_path, label_name), "w") as label_file:
                label_file.write("\n".join(labels))

        for i in range(10):
            bg_file = choice(background_files)
            background = cv2.imread(os.path.join(background_path, bg_file))
            background = cv2.resize(background, (640, 480))

            other_classes = sample([c for c in fraunhofer_paths.keys() if c != class_id], 2)
            composite_image, labels = create_composite_image(background, [class_id] + other_classes)

            image_name = f"class_{class_id}_trio_{i}.jpg"
            label_name = f"class_{class_id}_trio_{i}.txt"

            cv2.imwrite(os.path.join(output_images_path, image_name), composite_image)
            with open(os.path.join(output_labels_path, label_name), "w") as label_file:
                label_file.write("\n".join(labels))

# Generiere alle Bilder
generate_images()
