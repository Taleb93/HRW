# %%
import os

# Basisverzeichnis für den Dataset-Ordner
base_dir = "picks/dataset"

# Klassenbezeichnungen (die tatsächlichen Namen der Klassen)
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen",
    "ampel_rot",
    "ampel_gelb",
    "ampel_gruen",
]

# Unterordner für den Dataset-Aufbau
subfolders = ["input_autos", "input_pflanzen", "output"]

# Verzeichnisstruktur erstellen
for split in ["train", "val"]:  # train und val als Datensplits
    split_dir = os.path.join(base_dir, split)
    for cls in classes:
        class_dir = os.path.join(split_dir, cls)
        for subfolder in subfolders:
            folder_path = os.path.join(class_dir, subfolder)
            os.makedirs(folder_path, exist_ok=True)

print(f"Dataset-Struktur erfolgreich erstellt unter: {base_dir}")
# Out:
# Dataset-Struktur erfolgreich erstellt unter: picks/dataset

# %%
import os
import cv2

# Pfade zu den Eingabe- und Ausgabeverzeichnissen
images_dir = r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Cycles\153_FussgaengerueberwegLinks"
masks_dir = r"C:\Uni\python\Trafic sigs Detection\Dataset\klassifizierung\Frauenhof\Images\SynsetSignsetGermany\Masks\153_FussgaengerueberwegLinks"
#output_dir = r"picks/dataset/train/geradeaus_links/output"
output_dir = r"picks/dataset/tempL"

# Erstelle den Ausgabeordner, falls er nicht existiert
os.makedirs(output_dir, exist_ok=True)

# Durchlaufe die Bilder im Images-Ordner
for image_filename in os.listdir(images_dir):
    # Prüfe, ob die Datei eine PNG-Datei ist und den erwarteten Namen enthält
    if image_filename.endswith("_cycles.png"):
        # Extrahiere die Nummer aus dem Bildnamen
        image_num = image_filename.split("_")[0]  # Z. B. "0" aus "0_cycles.png"

        # Erstelle den entsprechenden Maskennamen
        mask_filename = f"{image_num}_msk.png"
        mask_path = os.path.join(masks_dir, mask_filename)
        image_path = os.path.join(images_dir, image_filename)

        # Lade das Bild und die Maske
        image = cv2.imread(image_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Maske als Graustufenbild laden

        if image is None or mask is None:
            print(f"Fehler beim Laden von: {image_path} oder {mask_path}")
            continue

        # Finde die Bounding Box der Maske
        x, y, w, h = cv2.boundingRect(mask)

        # Schneide den Bereich des Originalbildes basierend auf der Bounding Box aus
        cropped_image = image[y:y+h, x:x+w]

        # Speichere das zugeschnittene Bild im Ausgabeordner
        output_path = os.path.join(output_dir, f"cropped_{image_num}.png")
        cv2.imwrite(output_path, cropped_image)

        print(f"Gespeichert: {output_path}")
# Out:
# Gespeichert: picks/dataset/tempL\cropped_0.png
# Gespeichert: picks/dataset/tempL\cropped_100.png
# Gespeichert: picks/dataset/tempL\cropped_101.png
# Gespeichert: picks/dataset/tempL\cropped_102.png
# Gespeichert: picks/dataset/tempL\cropped_103.png
# Gespeichert: picks/dataset/tempL\cropped_104.png
# Gespeichert: picks/dataset/tempL\cropped_105.png
# Gespeichert: picks/dataset/tempL\cropped_106.png
# Gespeichert: picks/dataset/tempL\cropped_107.png
# Gespeichert: picks/dataset/tempL\cropped_108.png
# Gespeichert: picks/dataset/tempL\cropped_109.png
# Gespeichert: picks/dataset/tempL\cropped_10.png
# Gespeichert: picks/dataset/tempL\cropped_110.png
# Gespeichert: picks/dataset/tempL\cropped_111.png
# Gespeichert: picks/dataset/tempL\cropped_112.png
# Gespeichert: picks/dataset/tempL\cropped_113.png
# Gespeichert: picks/dataset/tempL\cropped_114.png
# Gespeichert: picks/dataset/tempL\cropped_115.png
# Gespeichert: picks/dataset/tempL\cropped_116.png
# Gespeichert: picks/dataset/tempL\cropped_117.png
# Gespeichert: picks/dataset/tempL\cropped_118.png
# Gespeichert: picks/dataset/tempL\cropped_119.png
# Gespeichert: picks/dataset/tempL\cropped_11.png
# Gespeichert: picks/dataset/tempL\cropped_120.png
# Gespeichert: picks/dataset/tempL\cropped_121.png
# Gespeichert: picks/dataset/tempL\cropped_122.png
# Gespeichert: picks/dataset/tempL\cropped_123.png
# Gespeichert: picks/dataset/tempL\cropped_124.png
# Gespeichert: picks/dataset/tempL\cropped_125.png
# Gespeichert: picks/dataset/tempL\cropped_126.png
# Gespeichert: picks/dataset/tempL\cropped_127.png
# Gespeichert: picks/dataset/tempL\cropped_128.png
# Gespeichert: picks/dataset/tempL\cropped_129.png
# Gespeichert: picks/dataset/tempL\cropped_12.png
# Gespeichert: picks/dataset/tempL\cropped_130.png
# Gespeichert: picks/dataset/tempL\cropped_131.png
# Gespeichert: picks/dataset/tempL\cropped_132.png
# Gespeichert: picks/dataset/tempL\cropped_133.png
# Gespeichert: picks/dataset/tempL\cropped_134.png
# Gespeichert: picks/dataset/tempL\cropped_135.png
# Gespeichert: picks/dataset/tempL\cropped_136.png
# Gespeichert: picks/dataset/tempL\cropped_137.png
# Gespeichert: picks/dataset/tempL\cropped_138.png
# Gespeichert: picks/dataset/tempL\cropped_139.png
# Gespeichert: picks/dataset/tempL\cropped_13.png
# Gespeichert: picks/dataset/tempL\cropped_140.png
# Gespeichert: picks/dataset/tempL\cropped_141.png
# Gespeichert: picks/dataset/tempL\cropped_142.png
# Gespeichert: picks/dataset/tempL\cropped_143.png
# Gespeichert: picks/dataset/tempL\cropped_144.png
# Gespeichert: picks/dataset/tempL\cropped_145.png
# Gespeichert: picks/dataset/tempL\cropped_146.png
# Gespeichert: picks/dataset/tempL\cropped_147.png
# Gespeichert: picks/dataset/tempL\cropped_148.png
# Gespeichert: picks/dataset/tempL\cropped_149.png
# Gespeichert: picks/dataset/tempL\cropped_14.png
# Gespeichert: picks/dataset/tempL\cropped_150.png
# Gespeichert: picks/dataset/tempL\cropped_151.png
# Gespeichert: picks/dataset/tempL\cropped_152.png
# Gespeichert: picks/dataset/tempL\cropped_153.png
# Gespeichert: picks/dataset/tempL\cropped_154.png
# Gespeichert: picks/dataset/tempL\cropped_155.png
# Gespeichert: picks/dataset/tempL\cropped_156.png
# Gespeichert: picks/dataset/tempL\cropped_157.png
# Gespeichert: picks/dataset/tempL\cropped_158.png
# Gespeichert: picks/dataset/tempL\cropped_159.png
# Gespeichert: picks/dataset/tempL\cropped_15.png
# Gespeichert: picks/dataset/tempL\cropped_160.png
# Gespeichert: picks/dataset/tempL\cropped_161.png
# Gespeichert: picks/dataset/tempL\cropped_162.png
# Gespeichert: picks/dataset/tempL\cropped_163.png
# Gespeichert: picks/dataset/tempL\cropped_164.png
# Gespeichert: picks/dataset/tempL\cropped_165.png
# Gespeichert: picks/dataset/tempL\cropped_166.png
# Gespeichert: picks/dataset/tempL\cropped_167.png
# Gespeichert: picks/dataset/tempL\cropped_168.png
# Gespeichert: picks/dataset/tempL\cropped_169.png
# Gespeichert: picks/dataset/tempL\cropped_16.png
# Gespeichert: picks/dataset/tempL\cropped_170.png
# Gespeichert: picks/dataset/tempL\cropped_171.png
# Gespeichert: picks/dataset/tempL\cropped_172.png
# Gespeichert: picks/dataset/tempL\cropped_173.png
# Gespeichert: picks/dataset/tempL\cropped_174.png
# Gespeichert: picks/dataset/tempL\cropped_175.png
# Gespeichert: picks/dataset/tempL\cropped_176.png
# Gespeichert: picks/dataset/tempL\cropped_177.png
# Gespeichert: picks/dataset/tempL\cropped_178.png
# Gespeichert: picks/dataset/tempL\cropped_179.png
# Gespeichert: picks/dataset/tempL\cropped_17.png
# Gespeichert: picks/dataset/tempL\cropped_180.png
# Gespeichert: picks/dataset/tempL\cropped_181.png
# Gespeichert: picks/dataset/tempL\cropped_182.png
# Gespeichert: picks/dataset/tempL\cropped_183.png
# Gespeichert: picks/dataset/tempL\cropped_184.png
# Gespeichert: picks/dataset/tempL\cropped_185.png
# Gespeichert: picks/dataset/tempL\cropped_186.png
# Gespeichert: picks/dataset/tempL\cropped_187.png
# Gespeichert: picks/dataset/tempL\cropped_188.png
# Gespeichert: picks/dataset/tempL\cropped_189.png
# Gespeichert: picks/dataset/tempL\cropped_18.png
# Gespeichert: picks/dataset/tempL\cropped_190.png
# Gespeichert: picks/dataset/tempL\cropped_191.png
# Gespeichert: picks/dataset/tempL\cropped_192.png
# Gespeichert: picks/dataset/tempL\cropped_193.png
# Gespeichert: picks/dataset/tempL\cropped_194.png
# Gespeichert: picks/dataset/tempL\cropped_195.png
# Gespeichert: picks/dataset/tempL\cropped_196.png
# Gespeichert: picks/dataset/tempL\cropped_197.png
# Gespeichert: picks/dataset/tempL\cropped_198.png
# Gespeichert: picks/dataset/tempL\cropped_199.png
# Gespeichert: picks/dataset/tempL\cropped_19.png
# Gespeichert: picks/dataset/tempL\cropped_1.png
# Gespeichert: picks/dataset/tempL\cropped_200.png
# Gespeichert: picks/dataset/tempL\cropped_201.png
# Gespeichert: picks/dataset/tempL\cropped_202.png
# Gespeichert: picks/dataset/tempL\cropped_203.png
# Gespeichert: picks/dataset/tempL\cropped_204.png
# Gespeichert: picks/dataset/tempL\cropped_205.png
# Gespeichert: picks/dataset/tempL\cropped_206.png
# Gespeichert: picks/dataset/tempL\cropped_207.png
# Gespeichert: picks/dataset/tempL\cropped_208.png
# Gespeichert: picks/dataset/tempL\cropped_209.png
# Gespeichert: picks/dataset/tempL\cropped_20.png
# Gespeichert: picks/dataset/tempL\cropped_210.png
# Gespeichert: picks/dataset/tempL\cropped_211.png
# Gespeichert: picks/dataset/tempL\cropped_212.png
# Gespeichert: picks/dataset/tempL\cropped_213.png
# Gespeichert: picks/dataset/tempL\cropped_214.png
# Gespeichert: picks/dataset/tempL\cropped_215.png
# Gespeichert: picks/dataset/tempL\cropped_216.png
# Gespeichert: picks/dataset/tempL\cropped_217.png
# Gespeichert: picks/dataset/tempL\cropped_218.png
# Gespeichert: picks/dataset/tempL\cropped_219.png
# Gespeichert: picks/dataset/tempL\cropped_21.png
# Gespeichert: picks/dataset/tempL\cropped_220.png
# Gespeichert: picks/dataset/tempL\cropped_221.png
# Gespeichert: picks/dataset/tempL\cropped_222.png
# Gespeichert: picks/dataset/tempL\cropped_223.png
# Gespeichert: picks/dataset/tempL\cropped_224.png
# Gespeichert: picks/dataset/tempL\cropped_225.png
# Gespeichert: picks/dataset/tempL\cropped_226.png
# Gespeichert: picks/dataset/tempL\cropped_227.png
# Gespeichert: picks/dataset/tempL\cropped_228.png
# Gespeichert: picks/dataset/tempL\cropped_229.png
# Gespeichert: picks/dataset/tempL\cropped_22.png
# Gespeichert: picks/dataset/tempL\cropped_230.png
# Gespeichert: picks/dataset/tempL\cropped_231.png
# Gespeichert: picks/dataset/tempL\cropped_232.png
# Gespeichert: picks/dataset/tempL\cropped_233.png
# Gespeichert: picks/dataset/tempL\cropped_234.png
# Gespeichert: picks/dataset/tempL\cropped_235.png
# Gespeichert: picks/dataset/tempL\cropped_236.png
# Gespeichert: picks/dataset/tempL\cropped_237.png
# Gespeichert: picks/dataset/tempL\cropped_238.png
# Gespeichert: picks/dataset/tempL\cropped_239.png
# Gespeichert: picks/dataset/tempL\cropped_23.png
# Gespeichert: picks/dataset/tempL\cropped_240.png
# Gespeichert: picks/dataset/tempL\cropped_241.png
# Gespeichert: picks/dataset/tempL\cropped_242.png
# Gespeichert: picks/dataset/tempL\cropped_243.png
# Gespeichert: picks/dataset/tempL\cropped_244.png
# Gespeichert: picks/dataset/tempL\cropped_245.png
# Gespeichert: picks/dataset/tempL\cropped_246.png
# Gespeichert: picks/dataset/tempL\cropped_247.png
# Gespeichert: picks/dataset/tempL\cropped_248.png
# Gespeichert: picks/dataset/tempL\cropped_249.png
# Gespeichert: picks/dataset/tempL\cropped_24.png
# Gespeichert: picks/dataset/tempL\cropped_250.png
# Gespeichert: picks/dataset/tempL\cropped_251.png
# Gespeichert: picks/dataset/tempL\cropped_252.png
# Gespeichert: picks/dataset/tempL\cropped_253.png
# Gespeichert: picks/dataset/tempL\cropped_254.png
# Gespeichert: picks/dataset/tempL\cropped_255.png
# Gespeichert: picks/dataset/tempL\cropped_256.png
# Gespeichert: picks/dataset/tempL\cropped_257.png
# Gespeichert: picks/dataset/tempL\cropped_258.png
# Gespeichert: picks/dataset/tempL\cropped_259.png
# Gespeichert: picks/dataset/tempL\cropped_25.png
# Gespeichert: picks/dataset/tempL\cropped_260.png
# Gespeichert: picks/dataset/tempL\cropped_261.png
# Gespeichert: picks/dataset/tempL\cropped_262.png
# Gespeichert: picks/dataset/tempL\cropped_263.png
# Gespeichert: picks/dataset/tempL\cropped_264.png
# Gespeichert: picks/dataset/tempL\cropped_265.png
# Gespeichert: picks/dataset/tempL\cropped_266.png
# Gespeichert: picks/dataset/tempL\cropped_267.png
# Gespeichert: picks/dataset/tempL\cropped_268.png
# Gespeichert: picks/dataset/tempL\cropped_269.png
# Gespeichert: picks/dataset/tempL\cropped_26.png
# Gespeichert: picks/dataset/tempL\cropped_270.png
# Gespeichert: picks/dataset/tempL\cropped_271.png
# Gespeichert: picks/dataset/tempL\cropped_272.png
# Gespeichert: picks/dataset/tempL\cropped_273.png
# Gespeichert: picks/dataset/tempL\cropped_274.png
# Gespeichert: picks/dataset/tempL\cropped_275.png
# Gespeichert: picks/dataset/tempL\cropped_276.png
# Gespeichert: picks/dataset/tempL\cropped_277.png
# Gespeichert: picks/dataset/tempL\cropped_278.png
# Gespeichert: picks/dataset/tempL\cropped_279.png
# Gespeichert: picks/dataset/tempL\cropped_27.png
# Gespeichert: picks/dataset/tempL\cropped_280.png
# Gespeichert: picks/dataset/tempL\cropped_281.png
# Gespeichert: picks/dataset/tempL\cropped_282.png
# Gespeichert: picks/dataset/tempL\cropped_283.png
# Gespeichert: picks/dataset/tempL\cropped_284.png
# Gespeichert: picks/dataset/tempL\cropped_285.png
# Gespeichert: picks/dataset/tempL\cropped_286.png
# Gespeichert: picks/dataset/tempL\cropped_287.png
# Gespeichert: picks/dataset/tempL\cropped_288.png
# Gespeichert: picks/dataset/tempL\cropped_289.png
# Gespeichert: picks/dataset/tempL\cropped_28.png
# Gespeichert: picks/dataset/tempL\cropped_290.png
# Gespeichert: picks/dataset/tempL\cropped_291.png
# Gespeichert: picks/dataset/tempL\cropped_292.png
# Gespeichert: picks/dataset/tempL\cropped_293.png
# Gespeichert: picks/dataset/tempL\cropped_294.png
# Gespeichert: picks/dataset/tempL\cropped_295.png
# Gespeichert: picks/dataset/tempL\cropped_296.png
# Gespeichert: picks/dataset/tempL\cropped_297.png
# Gespeichert: picks/dataset/tempL\cropped_298.png
# Gespeichert: picks/dataset/tempL\cropped_299.png
# Gespeichert: picks/dataset/tempL\cropped_29.png
# Gespeichert: picks/dataset/tempL\cropped_2.png
# Gespeichert: picks/dataset/tempL\cropped_300.png
# Gespeichert: picks/dataset/tempL\cropped_301.png
# Gespeichert: picks/dataset/tempL\cropped_302.png
# Gespeichert: picks/dataset/tempL\cropped_303.png
# Gespeichert: picks/dataset/tempL\cropped_304.png
# Gespeichert: picks/dataset/tempL\cropped_305.png
# Gespeichert: picks/dataset/tempL\cropped_306.png
# Gespeichert: picks/dataset/tempL\cropped_307.png
# Gespeichert: picks/dataset/tempL\cropped_308.png
# Gespeichert: picks/dataset/tempL\cropped_309.png
# Gespeichert: picks/dataset/tempL\cropped_30.png
# Gespeichert: picks/dataset/tempL\cropped_310.png
# Gespeichert: picks/dataset/tempL\cropped_311.png
# Gespeichert: picks/dataset/tempL\cropped_312.png
# Gespeichert: picks/dataset/tempL\cropped_313.png
# Gespeichert: picks/dataset/tempL\cropped_314.png
# Gespeichert: picks/dataset/tempL\cropped_315.png
# Gespeichert: picks/dataset/tempL\cropped_316.png
# Gespeichert: picks/dataset/tempL\cropped_317.png
# Gespeichert: picks/dataset/tempL\cropped_318.png
# Gespeichert: picks/dataset/tempL\cropped_319.png
# Gespeichert: picks/dataset/tempL\cropped_31.png
# Gespeichert: picks/dataset/tempL\cropped_320.png
# Gespeichert: picks/dataset/tempL\cropped_321.png
# Gespeichert: picks/dataset/tempL\cropped_322.png
# Gespeichert: picks/dataset/tempL\cropped_323.png
# Gespeichert: picks/dataset/tempL\cropped_324.png
# Gespeichert: picks/dataset/tempL\cropped_325.png
# Gespeichert: picks/dataset/tempL\cropped_326.png
# Gespeichert: picks/dataset/tempL\cropped_327.png
# Gespeichert: picks/dataset/tempL\cropped_328.png
# Gespeichert: picks/dataset/tempL\cropped_329.png
# Gespeichert: picks/dataset/tempL\cropped_32.png
# Gespeichert: picks/dataset/tempL\cropped_330.png
# Gespeichert: picks/dataset/tempL\cropped_331.png
# Gespeichert: picks/dataset/tempL\cropped_332.png
# Gespeichert: picks/dataset/tempL\cropped_333.png
# Gespeichert: picks/dataset/tempL\cropped_334.png
# Gespeichert: picks/dataset/tempL\cropped_335.png
# Gespeichert: picks/dataset/tempL\cropped_336.png
# Gespeichert: picks/dataset/tempL\cropped_337.png
# Gespeichert: picks/dataset/tempL\cropped_338.png
# Gespeichert: picks/dataset/tempL\cropped_339.png
# Gespeichert: picks/dataset/tempL\cropped_33.png
# Gespeichert: picks/dataset/tempL\cropped_340.png
# Gespeichert: picks/dataset/tempL\cropped_341.png
# Gespeichert: picks/dataset/tempL\cropped_342.png
# Gespeichert: picks/dataset/tempL\cropped_343.png
# Gespeichert: picks/dataset/tempL\cropped_344.png
# Gespeichert: picks/dataset/tempL\cropped_345.png
# Gespeichert: picks/dataset/tempL\cropped_346.png
# Gespeichert: picks/dataset/tempL\cropped_347.png
# Gespeichert: picks/dataset/tempL\cropped_348.png
# Gespeichert: picks/dataset/tempL\cropped_349.png
# Gespeichert: picks/dataset/tempL\cropped_34.png
# Gespeichert: picks/dataset/tempL\cropped_350.png
# Gespeichert: picks/dataset/tempL\cropped_351.png
# Gespeichert: picks/dataset/tempL\cropped_352.png
# Gespeichert: picks/dataset/tempL\cropped_353.png
# Gespeichert: picks/dataset/tempL\cropped_354.png
# Gespeichert: picks/dataset/tempL\cropped_355.png
# Gespeichert: picks/dataset/tempL\cropped_356.png
# Gespeichert: picks/dataset/tempL\cropped_357.png
# Gespeichert: picks/dataset/tempL\cropped_358.png
# Gespeichert: picks/dataset/tempL\cropped_359.png
# Gespeichert: picks/dataset/tempL\cropped_35.png
# Gespeichert: picks/dataset/tempL\cropped_360.png
# Gespeichert: picks/dataset/tempL\cropped_361.png
# Gespeichert: picks/dataset/tempL\cropped_362.png
# Gespeichert: picks/dataset/tempL\cropped_363.png
# Gespeichert: picks/dataset/tempL\cropped_364.png
# Gespeichert: picks/dataset/tempL\cropped_365.png
# Gespeichert: picks/dataset/tempL\cropped_366.png
# Gespeichert: picks/dataset/tempL\cropped_367.png
# Gespeichert: picks/dataset/tempL\cropped_368.png
# Gespeichert: picks/dataset/tempL\cropped_369.png
# Gespeichert: picks/dataset/tempL\cropped_36.png
# Gespeichert: picks/dataset/tempL\cropped_370.png
# Gespeichert: picks/dataset/tempL\cropped_371.png
# Gespeichert: picks/dataset/tempL\cropped_372.png
# Gespeichert: picks/dataset/tempL\cropped_373.png
# Gespeichert: picks/dataset/tempL\cropped_374.png
# Gespeichert: picks/dataset/tempL\cropped_375.png
# Gespeichert: picks/dataset/tempL\cropped_376.png
# Gespeichert: picks/dataset/tempL\cropped_377.png
# Gespeichert: picks/dataset/tempL\cropped_378.png
# Gespeichert: picks/dataset/tempL\cropped_379.png
# Gespeichert: picks/dataset/tempL\cropped_37.png
# Gespeichert: picks/dataset/tempL\cropped_380.png
# Gespeichert: picks/dataset/tempL\cropped_381.png
# Gespeichert: picks/dataset/tempL\cropped_382.png
# Gespeichert: picks/dataset/tempL\cropped_383.png
# Gespeichert: picks/dataset/tempL\cropped_384.png
# Gespeichert: picks/dataset/tempL\cropped_385.png
# Gespeichert: picks/dataset/tempL\cropped_386.png
# Gespeichert: picks/dataset/tempL\cropped_387.png
# Gespeichert: picks/dataset/tempL\cropped_388.png
# Gespeichert: picks/dataset/tempL\cropped_389.png
# Gespeichert: picks/dataset/tempL\cropped_38.png
# Gespeichert: picks/dataset/tempL\cropped_390.png
# Gespeichert: picks/dataset/tempL\cropped_391.png
# Gespeichert: picks/dataset/tempL\cropped_392.png
# Gespeichert: picks/dataset/tempL\cropped_393.png
# Gespeichert: picks/dataset/tempL\cropped_394.png
# Gespeichert: picks/dataset/tempL\cropped_395.png
# Gespeichert: picks/dataset/tempL\cropped_396.png
# Gespeichert: picks/dataset/tempL\cropped_397.png
# Gespeichert: picks/dataset/tempL\cropped_398.png
# Gespeichert: picks/dataset/tempL\cropped_399.png
# Gespeichert: picks/dataset/tempL\cropped_39.png
# Gespeichert: picks/dataset/tempL\cropped_3.png
# Gespeichert: picks/dataset/tempL\cropped_400.png
# Gespeichert: picks/dataset/tempL\cropped_401.png
# Gespeichert: picks/dataset/tempL\cropped_402.png
# Gespeichert: picks/dataset/tempL\cropped_403.png
# Gespeichert: picks/dataset/tempL\cropped_404.png
# Gespeichert: picks/dataset/tempL\cropped_405.png
# Gespeichert: picks/dataset/tempL\cropped_406.png
# Gespeichert: picks/dataset/tempL\cropped_407.png
# Gespeichert: picks/dataset/tempL\cropped_408.png
# Gespeichert: picks/dataset/tempL\cropped_409.png
# Gespeichert: picks/dataset/tempL\cropped_40.png
# Gespeichert: picks/dataset/tempL\cropped_410.png
# Gespeichert: picks/dataset/tempL\cropped_411.png
# Gespeichert: picks/dataset/tempL\cropped_412.png
# Gespeichert: picks/dataset/tempL\cropped_413.png
# Gespeichert: picks/dataset/tempL\cropped_414.png
# Gespeichert: picks/dataset/tempL\cropped_415.png
# Gespeichert: picks/dataset/tempL\cropped_416.png
# Gespeichert: picks/dataset/tempL\cropped_417.png
# Gespeichert: picks/dataset/tempL\cropped_418.png
# Gespeichert: picks/dataset/tempL\cropped_419.png
# Gespeichert: picks/dataset/tempL\cropped_41.png
# Gespeichert: picks/dataset/tempL\cropped_420.png
# Gespeichert: picks/dataset/tempL\cropped_421.png
# Gespeichert: picks/dataset/tempL\cropped_422.png
# Gespeichert: picks/dataset/tempL\cropped_423.png
# Gespeichert: picks/dataset/tempL\cropped_424.png
# Gespeichert: picks/dataset/tempL\cropped_425.png
# Gespeichert: picks/dataset/tempL\cropped_426.png
# Gespeichert: picks/dataset/tempL\cropped_427.png
# Gespeichert: picks/dataset/tempL\cropped_428.png
# Gespeichert: picks/dataset/tempL\cropped_429.png
# Gespeichert: picks/dataset/tempL\cropped_42.png
# Gespeichert: picks/dataset/tempL\cropped_430.png
# Gespeichert: picks/dataset/tempL\cropped_431.png
# Gespeichert: picks/dataset/tempL\cropped_432.png
# Gespeichert: picks/dataset/tempL\cropped_433.png
# Gespeichert: picks/dataset/tempL\cropped_434.png
# Gespeichert: picks/dataset/tempL\cropped_435.png
# Gespeichert: picks/dataset/tempL\cropped_436.png
# Gespeichert: picks/dataset/tempL\cropped_437.png
# Gespeichert: picks/dataset/tempL\cropped_438.png
# Gespeichert: picks/dataset/tempL\cropped_439.png
# Gespeichert: picks/dataset/tempL\cropped_43.png
# Gespeichert: picks/dataset/tempL\cropped_440.png
# Gespeichert: picks/dataset/tempL\cropped_441.png
# Gespeichert: picks/dataset/tempL\cropped_442.png
# Gespeichert: picks/dataset/tempL\cropped_443.png
# Gespeichert: picks/dataset/tempL\cropped_444.png
# Gespeichert: picks/dataset/tempL\cropped_445.png
# Gespeichert: picks/dataset/tempL\cropped_446.png
# Gespeichert: picks/dataset/tempL\cropped_447.png
# Gespeichert: picks/dataset/tempL\cropped_448.png
# Gespeichert: picks/dataset/tempL\cropped_449.png
# Gespeichert: picks/dataset/tempL\cropped_44.png
# Gespeichert: picks/dataset/tempL\cropped_450.png
# Gespeichert: picks/dataset/tempL\cropped_451.png
# Gespeichert: picks/dataset/tempL\cropped_452.png
# Gespeichert: picks/dataset/tempL\cropped_453.png
# Gespeichert: picks/dataset/tempL\cropped_454.png
# Gespeichert: picks/dataset/tempL\cropped_455.png
# Gespeichert: picks/dataset/tempL\cropped_456.png
# Gespeichert: picks/dataset/tempL\cropped_457.png
# Gespeichert: picks/dataset/tempL\cropped_458.png
# Gespeichert: picks/dataset/tempL\cropped_459.png
# Gespeichert: picks/dataset/tempL\cropped_45.png
# Gespeichert: picks/dataset/tempL\cropped_460.png
# Gespeichert: picks/dataset/tempL\cropped_461.png
# Gespeichert: picks/dataset/tempL\cropped_462.png
# Gespeichert: picks/dataset/tempL\cropped_463.png
# Gespeichert: picks/dataset/tempL\cropped_464.png
# Gespeichert: picks/dataset/tempL\cropped_465.png
# Gespeichert: picks/dataset/tempL\cropped_466.png
# Gespeichert: picks/dataset/tempL\cropped_467.png
# Gespeichert: picks/dataset/tempL\cropped_468.png
# Gespeichert: picks/dataset/tempL\cropped_469.png
# Gespeichert: picks/dataset/tempL\cropped_46.png
# Gespeichert: picks/dataset/tempL\cropped_470.png
# Gespeichert: picks/dataset/tempL\cropped_471.png
# Gespeichert: picks/dataset/tempL\cropped_472.png
# Gespeichert: picks/dataset/tempL\cropped_473.png
# Gespeichert: picks/dataset/tempL\cropped_474.png
# Gespeichert: picks/dataset/tempL\cropped_475.png
# Gespeichert: picks/dataset/tempL\cropped_476.png
# Gespeichert: picks/dataset/tempL\cropped_477.png
# Gespeichert: picks/dataset/tempL\cropped_478.png
# Gespeichert: picks/dataset/tempL\cropped_479.png
# Gespeichert: picks/dataset/tempL\cropped_47.png
# Gespeichert: picks/dataset/tempL\cropped_480.png
# Gespeichert: picks/dataset/tempL\cropped_481.png
# Gespeichert: picks/dataset/tempL\cropped_482.png
# Gespeichert: picks/dataset/tempL\cropped_483.png
# Gespeichert: picks/dataset/tempL\cropped_484.png
# Gespeichert: picks/dataset/tempL\cropped_485.png
# Gespeichert: picks/dataset/tempL\cropped_486.png
# Gespeichert: picks/dataset/tempL\cropped_487.png
# Gespeichert: picks/dataset/tempL\cropped_488.png
# Gespeichert: picks/dataset/tempL\cropped_489.png
# Gespeichert: picks/dataset/tempL\cropped_48.png
# Gespeichert: picks/dataset/tempL\cropped_490.png
# Gespeichert: picks/dataset/tempL\cropped_491.png
# Gespeichert: picks/dataset/tempL\cropped_492.png
# Gespeichert: picks/dataset/tempL\cropped_493.png
# Gespeichert: picks/dataset/tempL\cropped_494.png
# Gespeichert: picks/dataset/tempL\cropped_495.png
# Gespeichert: picks/dataset/tempL\cropped_496.png
# Gespeichert: picks/dataset/tempL\cropped_497.png
# Gespeichert: picks/dataset/tempL\cropped_498.png
# Gespeichert: picks/dataset/tempL\cropped_499.png
# Gespeichert: picks/dataset/tempL\cropped_49.png
# Gespeichert: picks/dataset/tempL\cropped_4.png
# Gespeichert: picks/dataset/tempL\cropped_50.png
# Gespeichert: picks/dataset/tempL\cropped_51.png
# Gespeichert: picks/dataset/tempL\cropped_52.png
# Gespeichert: picks/dataset/tempL\cropped_53.png
# Gespeichert: picks/dataset/tempL\cropped_54.png
# Gespeichert: picks/dataset/tempL\cropped_55.png
# Gespeichert: picks/dataset/tempL\cropped_56.png
# Gespeichert: picks/dataset/tempL\cropped_57.png
# Gespeichert: picks/dataset/tempL\cropped_58.png
# Gespeichert: picks/dataset/tempL\cropped_59.png
# Gespeichert: picks/dataset/tempL\cropped_5.png
# Gespeichert: picks/dataset/tempL\cropped_60.png
# Gespeichert: picks/dataset/tempL\cropped_61.png
# Gespeichert: picks/dataset/tempL\cropped_62.png
# Gespeichert: picks/dataset/tempL\cropped_63.png
# Gespeichert: picks/dataset/tempL\cropped_64.png
# Gespeichert: picks/dataset/tempL\cropped_65.png
# Gespeichert: picks/dataset/tempL\cropped_66.png
# Gespeichert: picks/dataset/tempL\cropped_67.png
# Gespeichert: picks/dataset/tempL\cropped_68.png
# Gespeichert: picks/dataset/tempL\cropped_69.png
# Gespeichert: picks/dataset/tempL\cropped_6.png
# Gespeichert: picks/dataset/tempL\cropped_70.png
# Gespeichert: picks/dataset/tempL\cropped_71.png
# Gespeichert: picks/dataset/tempL\cropped_72.png
# Gespeichert: picks/dataset/tempL\cropped_73.png
# Gespeichert: picks/dataset/tempL\cropped_74.png
# Gespeichert: picks/dataset/tempL\cropped_75.png
# Gespeichert: picks/dataset/tempL\cropped_76.png
# Gespeichert: picks/dataset/tempL\cropped_77.png
# Gespeichert: picks/dataset/tempL\cropped_78.png
# Gespeichert: picks/dataset/tempL\cropped_79.png
# Gespeichert: picks/dataset/tempL\cropped_7.png
# Gespeichert: picks/dataset/tempL\cropped_80.png
# Gespeichert: picks/dataset/tempL\cropped_81.png
# Gespeichert: picks/dataset/tempL\cropped_82.png
# Gespeichert: picks/dataset/tempL\cropped_83.png
# Gespeichert: picks/dataset/tempL\cropped_84.png
# Gespeichert: picks/dataset/tempL\cropped_85.png
# Gespeichert: picks/dataset/tempL\cropped_86.png
# Gespeichert: picks/dataset/tempL\cropped_87.png
# Gespeichert: picks/dataset/tempL\cropped_88.png
# Gespeichert: picks/dataset/tempL\cropped_89.png
# Gespeichert: picks/dataset/tempL\cropped_8.png
# Gespeichert: picks/dataset/tempL\cropped_90.png
# Gespeichert: picks/dataset/tempL\cropped_91.png
# Gespeichert: picks/dataset/tempL\cropped_92.png
# Gespeichert: picks/dataset/tempL\cropped_93.png
# Gespeichert: picks/dataset/tempL\cropped_94.png
# Gespeichert: picks/dataset/tempL\cropped_95.png
# Gespeichert: picks/dataset/tempL\cropped_96.png
# Gespeichert: picks/dataset/tempL\cropped_97.png
# Gespeichert: picks/dataset/tempL\cropped_98.png
# Gespeichert: picks/dataset/tempL\cropped_99.png
# Gespeichert: picks/dataset/tempL\cropped_9.png

# %%
import os
from PIL import Image
from pillow_heif import register_heif_opener

# HEIC-Unterstützung registrieren
register_heif_opener()

# Quell- und Zielpfad
source_folder = r"C:\Uni\python\masked autoencoder\picks\masskinig"
output_folder = os.path.join(source_folder, "converted_pngs")
os.makedirs(output_folder, exist_ok=True)

# Alle HEIC-Dateien konvertieren
for filename in os.listdir(source_folder):
    if filename.lower().endswith(".heic"):
        heic_path = os.path.join(source_folder, filename)
        png_path = os.path.join(output_folder, os.path.splitext(filename)[0] + ".png")

        with Image.open(heic_path) as img:
            img.save(png_path, "PNG")

print("Konvertierung abgeschlossen! PNG-Dateien sind im Ordner:", output_folder)
# Out:
# Konvertierung abgeschlossen! PNG-Dateien sind im Ordner: C:\Uni\python\masked autoencoder\picks\masskinig\converted_pngs

# %%
import os
from PIL import Image

# Quell- und Zielordner
source_folder = r"C:\Uni\python\masked autoencoder\picks\masskinig\links"
output_folder = r"C:\Uni\python\masked autoencoder\picks\masskinig\rechts"
os.makedirs(output_folder, exist_ok=True)

# Alle Bilder im Quellordner spiegeln
for filename in os.listdir(source_folder):
    if filename.lower().endswith((".png")):
        source_path = os.path.join(source_folder, filename)
        output_path = os.path.join(output_folder, filename)

        with Image.open(source_path) as img:
            mirrored_img = img.transpose(Image.FLIP_LEFT_RIGHT)
            mirrored_img.save(output_path)

print("Spiegelung abgeschlossen! Neue Bilder sind im Ordner:", output_folder)
# Out:
# Spiegelung abgeschlossen! Neue Bilder sind im Ordner: C:\Uni\python\masked autoencoder\picks\masskinig\rechts

# %%
import os

# Basisverzeichnis des Datasets
base_dir = "picks/dataset/train"

# Klassenordner
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen"
]

# Zähle die Bilder in jedem `output`-Ordner
for class_name in classes:
    class_dir = os.path.join(base_dir, class_name, "output")
    if os.path.exists(class_dir):
        num_images = len([f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))])
        print(f"Klasse '{class_name}'in Output: {num_images} Bilder")
    else:
        print(f"Klasse '{class_name}' hat keinen `output`-Ordner.")
# Out:
# Klasse 'rechts_abbiegen'in Output: 500 Bilder
# Klasse 'links_abbiegen'in Output: 500 Bilder
# Klasse 'geradeaus'in Output: 500 Bilder
# Klasse 'geradeaus_rechts'in Output: 500 Bilder
# Klasse 'geradeaus_links'in Output: 500 Bilder
# Klasse 'zebrastreifen'in Output: 500 Bilder

# %%
import os

# Basisverzeichnis des Datasets
base_dir = "picks/dataset/train"

# Klassenordner
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen"
]

# Zähle die Bilder in jedem `output`-Ordner
for class_name in classes:
    class_dir = os.path.join(base_dir, class_name, "input")
    if os.path.exists(class_dir):
        num_images = len([f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))])
        print(f"Klasse '{class_name}'in Input: {num_images} Bilder")
    else:
        print(f"Klasse '{class_name}' hat keinen `output`-Ordner.")
# Out:
# Klasse 'rechts_abbiegen'in Input: 195 Bilder
# Klasse 'links_abbiegen'in Input: 174 Bilder
# Klasse 'geradeaus'in Input: 152 Bilder
# Klasse 'geradeaus_rechts'in Input: 235 Bilder
# Klasse 'geradeaus_links'in Input: 248 Bilder
# Klasse 'zebrastreifen'in Input: 205 Bilder

# %%
import os
import random
from PIL import Image, ImageEnhance

# Basisverzeichnis
base_dir = "picks/dataset/train"

# Klassen und Zielanzahl (alle Klassen sollen die gleiche Anzahl Bilder haben)
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen"
]
target_count = 650   # Zielanzahl basierend auf der größten Klasse

# Funktion zur Augmentation (Helligkeitsanpassung)
def augment_image(image_path, output_path, augmentation_id):
    image = Image.open(image_path).convert("RGB")
    
    # Helligkeit zufällig ändern
    brightness_factor = random.uniform(0.8, 1.2)  # 80% bis 120% Helligkeit
    enhancer = ImageEnhance.Brightness(image)
    augmented_image = enhancer.enhance(brightness_factor)
    
    # Speichern der augmentierten Version
    augmented_image.save(output_path)

# Bilder umbenennen und durch Augmentation ausgleichen
for class_name in classes:
    class_dir = os.path.join(base_dir, class_name, "output")
    images = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]

    # Umbenennen der Bilder
    #for i, image in enumerate(images):
        #new_name = f"{class_name}_{i+1}.png"
        #os.rename(os.path.join(class_dir, image), os.path.join(class_dir, new_name))

    # Anzahl der Bilder überprüfen
    images = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f))]
    current_count = len(images)

    # Fehlende Bilder augmentieren
    if current_count < target_count:
        augment_needed = target_count - current_count
        print(f"Augmentiere {augment_needed} Bilder für die Klasse {class_name}.")
        
        for i in range(augment_needed):
            # Wähle ein zufälliges Basisbild für die Augmentation
            src_image = random.choice(images)
            src_path = os.path.join(class_dir, src_image)
            dst_path = os.path.join(class_dir, f"{class_name}_augmentted_{i+1}.png")
            
            # Augmentation anwenden
            augment_image(src_path, dst_path, i + 1)

    print(f"Klasse '{class_name}' hat jetzt {target_count} Bilder.")
# Out:
# Augmentiere 150 Bilder für die Klasse rechts_abbiegen.
# Klasse 'rechts_abbiegen' hat jetzt 650 Bilder.
# Augmentiere 150 Bilder für die Klasse links_abbiegen.
# Klasse 'links_abbiegen' hat jetzt 650 Bilder.
# Augmentiere 150 Bilder für die Klasse geradeaus.
# Klasse 'geradeaus' hat jetzt 650 Bilder.
# Augmentiere 150 Bilder für die Klasse geradeaus_rechts.
# Klasse 'geradeaus_rechts' hat jetzt 650 Bilder.
# Augmentiere 150 Bilder für die Klasse geradeaus_links.
# Klasse 'geradeaus_links' hat jetzt 650 Bilder.
# Augmentiere 150 Bilder für die Klasse zebrastreifen.
# Klasse 'zebrastreifen' hat jetzt 650 Bilder.

# %%
import os
import shutil

# Basisverzeichnisse
source_base_dir = r"C:\Uni\python\masked autoencoder\picks\masskinig"
target_base_dir = r"C:\Uni\python\masked autoencoder\picks\dataset\train"

# Zuordnung der Ordnernamen zwischen Quell- und Zielverzeichnis
folder_mapping = {
    "gerade": "geradeaus",
    "gerade_links": "geradeaus_links",
    "gerade_rechts": "geradeaus_rechts",
    "links": "links_abbiegen",
    "rechts": "rechts_abbiegen",
    "zebra": "zebrastreifen"
}

# Verarbeitung der Ordner
for source_folder, target_folder in folder_mapping.items():
    source_path = os.path.join(source_base_dir, source_folder)
    target_path = os.path.join(target_base_dir, target_folder)

    # Zielordner für 'input' und 'output'
    input_dir = os.path.join(target_path, "input")
    output_dir = os.path.join(target_path, "output")

    # Erstelle die Ordner 'input' und 'output', falls sie nicht existieren
    os.makedirs(input_dir, exist_ok=True)
    os.makedirs(output_dir, exist_ok=True)

    # Verschiebe Dateien aus dem Quellordner
    for file_name in os.listdir(source_path):
        file_path = os.path.join(source_path, file_name)

        # Überspringe Verzeichnisse
        if os.path.isdir(file_path):
            continue

        # Verschiebe 'mask_*.png'-Bilder in den 'input'-Ordner
        if file_name.startswith("mask_") and file_name.endswith(".png"):
            shutil.move(file_path, os.path.join(input_dir, file_name))

        # Verschiebe 'clear_*.png'-Bilder in den 'output'-Ordner
        elif file_name.startswith("clear_") and file_name.endswith(".png"):
            shutil.move(file_path, os.path.join(output_dir, file_name))

    print(f"Ordner '{source_folder}' -> '{target_folder}' erfolgreich verarbeitet.")

print("Alle Bilder erfolgreich verschoben!")
# Out:
# Ordner 'gerade' -> 'geradeaus' erfolgreich verarbeitet.
# Ordner 'gerade_links' -> 'geradeaus_links' erfolgreich verarbeitet.
# Ordner 'gerade_rechts' -> 'geradeaus_rechts' erfolgreich verarbeitet.
# Ordner 'links' -> 'links_abbiegen' erfolgreich verarbeitet.
# Ordner 'rechts' -> 'rechts_abbiegen' erfolgreich verarbeitet.
# Ordner 'zebra' -> 'zebrastreifen' erfolgreich verarbeitet.
# Alle Bilder erfolgreich verschoben!

# %%
import os
import shutil

# Basisverzeichnis
base_dir = r"C:\Uni\python\masked autoencoder\picks\masskinig"

# Liste der Ordner, die verarbeitet werden sollen
folders = ["gerade", "gerade_links", "gerade_rechts", "links", "rechts", "zebra"]

# Verarbeitung der Ordner
for folder in folders:
    class_path = os.path.join(base_dir, folder)
    
    if not os.path.isdir(class_path):
        print(f"Ordner '{folder}' existiert nicht. Übersprungen.")
        continue

    # Pfad zu `output.png`
    output_image_path = os.path.join(class_path, "output.png")
    if not os.path.exists(output_image_path):
        print(f"'{output_image_path}' nicht gefunden. Übersprungen.")
        continue

    # Zähle die maskierten Bilder im Ordner (alle PNG außer `output.png`)
    images = [f for f in os.listdir(class_path) if f.endswith(".png") and f != "output.png"]
    num_images = len(images)

    print(f"Verarbeite Ordner '{folder}': {num_images} maskierte Bilder gefunden.")

    # Kopiere `output.png` entsprechend oft und benenne die Dateien um
    for i, image_name in enumerate(images):
        new_output_name = f"clear_{i+1}.png"
        new_output_path = os.path.join(class_path, new_output_name)
        shutil.copy2(output_image_path, new_output_path)

    print(f"'{folder}': {num_images} Zielbilder erstellt.")

print("Fertig!")
# Out:
# Verarbeite Ordner 'gerade': 24 maskierte Bilder gefunden.
# 'gerade': 24 Zielbilder erstellt.
# Verarbeite Ordner 'gerade_links': 24 maskierte Bilder gefunden.
# 'gerade_links': 24 Zielbilder erstellt.
# Verarbeite Ordner 'gerade_rechts': 24 maskierte Bilder gefunden.
# 'gerade_rechts': 24 Zielbilder erstellt.
# Verarbeite Ordner 'links': 17 maskierte Bilder gefunden.
# 'links': 17 Zielbilder erstellt.
# Verarbeite Ordner 'rechts': 17 maskierte Bilder gefunden.
# 'rechts': 17 Zielbilder erstellt.
# Verarbeite Ordner 'zebra': 20 maskierte Bilder gefunden.
# 'zebra': 20 Zielbilder erstellt.
# Fertig!

# %%
import os

# Basisverzeichnis
base_dir = r"C:\Uni\python\masked autoencoder\picks\masskinig"

# Liste der Ordner, die verarbeitet werden sollen
folders = ["gerade", "gerade_links", "gerade_rechts", "links", "rechts", "zebra"]

# Verarbeitung der Ordner
for folder in folders:
    class_path = os.path.join(base_dir, folder)
    
    if not os.path.isdir(class_path):
        print(f"Ordner '{folder}' existiert nicht. Übersprungen.")
        continue

    # Pfad zu `output.png`
    output_image_path = os.path.join(class_path, "output.png")
    
    if os.path.exists(output_image_path):
        os.remove(output_image_path)
        print(f"'{output_image_path}' wurde gelöscht.")
    else:
        print(f"'{output_image_path}' nicht gefunden. Nichts zu löschen.")

print("Fertig!")
# Out:
# 'C:\Uni\python\masked autoencoder\picks\masskinig\gerade\output.png' wurde gelöscht.
# 'C:\Uni\python\masked autoencoder\picks\masskinig\gerade_links\output.png' wurde gelöscht.
# 'C:\Uni\python\masked autoencoder\picks\masskinig\gerade_rechts\output.png' wurde gelöscht.
# 'C:\Uni\python\masked autoencoder\picks\masskinig\links\output.png' wurde gelöscht.
# 'C:\Uni\python\masked autoencoder\picks\masskinig\rechts\output.png' wurde gelöscht.
# 'C:\Uni\python\masked autoencoder\picks\masskinig\zebra\output.png' wurde gelöscht.
# Fertig!

# %%
import os

# Basisverzeichnis
base_dir = r"C:\Uni\python\masked autoencoder\picks\masskinig"

# Liste der Ordner, die verarbeitet werden sollen
folders = ["gerade", "gerade_links", "gerade_rechts", "links", "rechts", "zebra"]

# Verarbeitung der Ordner
for folder in folders:
    class_path = os.path.join(base_dir, folder)
    
    if not os.path.isdir(class_path):
        print(f"Ordner '{folder}' existiert nicht. Übersprungen.")
        continue

    # Sammle alle Zielbilder (clear_X.png)
    clear_images = sorted([f for f in os.listdir(class_path) if f.startswith("clear_") and f.endswith(".png")])
    num_clear_images = len(clear_images)

    # Sammle alle nicht umbenannten maskierten Bilder (aktuell unbenannt)
    all_images = sorted([f for f in os.listdir(class_path) if f.endswith(".png")])
    masked_images = [img for img in all_images if not img.startswith("clear_")]

    if len(masked_images) != num_clear_images:
        print(f"Warnung: Anzahl maskierter Bilder ({len(masked_images)}) und Zielbilder ({num_clear_images}) stimmen in '{folder}' nicht überein.")
        continue

    # Maskierte Bilder umbenennen
    for idx, masked in enumerate(masked_images, start=1):
        new_masked_name = f"mask_{idx}.png"
        masked_path = os.path.join(class_path, masked)
        new_masked_path = os.path.join(class_path, new_masked_name)

        # Umbenennen
        os.rename(masked_path, new_masked_path)

    print(f"'{folder}': {len(masked_images)} maskierte Bilder erfolgreich umbenannt.")

print("Fertig!")
# Out:
# 'gerade': 24 maskierte Bilder erfolgreich umbenannt.
# 'gerade_links': 24 maskierte Bilder erfolgreich umbenannt.
# 'gerade_rechts': 24 maskierte Bilder erfolgreich umbenannt.
# 'links': 17 maskierte Bilder erfolgreich umbenannt.
# 'rechts': 17 maskierte Bilder erfolgreich umbenannt.
# 'zebra': 20 maskierte Bilder erfolgreich umbenannt.
# Fertig!

# %%
import os
import shutil
import random

# Basisverzeichnis
base_dir = r"C:\Uni\python\masked autoencoder\picks\dataset\train"

# Klassenordner
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen"
]

# Verarbeitung der Klassen
for class_name in classes:
    class_path = os.path.join(base_dir, class_name)
    input_dir = os.path.join(class_path, "input")
    output_dir = os.path.join(class_path, "output")
    nicht_sauber_dir = os.path.join(class_path, "nicht_sauber")

    # Erstelle die Ordner, falls sie nicht existieren
    os.makedirs(input_dir, exist_ok=True)
    os.makedirs(output_dir, exist_ok=True)

    # Sammle existierende mask_*.png und clear_*.png, um Nummern zu vermeiden
    existing_mask_numbers = {
        int(f.split("_")[1].split(".")[0])
        for f in os.listdir(input_dir) if f.startswith("mask_") and f.endswith(".png")
    }
    existing_clear_numbers = {
        int(f.split("_")[1].split(".")[0])
        for f in os.listdir(output_dir) if f.startswith("clear_") and f.endswith(".png")
    }

    # Maximal verwendete Nummern bestimmen
    max_mask_number = max(existing_mask_numbers, default=0)
    max_clear_number = max(existing_clear_numbers, default=0)

    # Verarbeite Bilder aus 'nicht_sauber/'
    if os.path.exists(nicht_sauber_dir):
        for file_name in os.listdir(nicht_sauber_dir):
            file_path = os.path.join(nicht_sauber_dir, file_name)

            # Neue Nummer für 'mask_*.png'
            max_mask_number += 1
            new_mask_name = f"mask_{max_mask_number}.png"
            new_mask_path = os.path.join(input_dir, new_mask_name)

            # Verschiebe Bild in 'input/' und benenne es um
            shutil.move(file_path, new_mask_path)

            # Zufälliges Bild aus 'output/' zuordnen, das noch keinen 'clear_*.png'-Namen hat
            output_candidates = [
                f for f in os.listdir(output_dir)
                if not f.startswith("clear_") and f.endswith(".png")
            ]

            if output_candidates:
                assigned_output = random.choice(output_candidates)
                assigned_output_path = os.path.join(output_dir, assigned_output)

                # Neue Nummer für 'clear_*.png'
                max_clear_number += 1
                new_clear_name = f"clear_{max_clear_number}.png"
                new_clear_path = os.path.join(output_dir, new_clear_name)

                # Benenne das zugewiesene Bild im 'output/'-Ordner um
                os.rename(assigned_output_path, new_clear_path)

        print(f"'{class_name}': {len(os.listdir(nicht_sauber_dir))} Bilder aus 'nicht_sauber/' verarbeitet.")

print("Alle Bilder erfolgreich verschoben und umbenannt!")

# %%
import os
import cv2

# Basisverzeichnis für den Dataset-Ordner
base_dir = "picks/dataset/train"

# Klassen, die bearbeitet werden sollen (ohne Ampelklassen)
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen"
]

# Zielgröße für die Bilder
target_size = (64, 64)  # Zielgröße für die Bilder

# Skalieren der Bilder für jede Klasse
for cls in classes:
    traffic_signs_dir = os.path.join(base_dir, cls, "input")  # Verzeichnis mit den Bildern der Klasse

    # Prüfen, ob das Verzeichnis existiert
    if not os.path.exists(traffic_signs_dir):
        print(f"Verzeichnis nicht gefunden: {traffic_signs_dir}")
        continue

    # Alle Bilder in der Klasse verarbeiten
    for image_filename in os.listdir(traffic_signs_dir):
        if image_filename.endswith(".png"):
            image_path = os.path.join(traffic_signs_dir, image_filename)

            # Lade das Bild
            image = cv2.imread(image_path)
            if image is None:
                print(f"Fehler beim Laden von: {image_path}")
                continue

            # Skalieren des Bildes auf die Zielgröße
            resized_image = cv2.resize(image, target_size)

            # Überschreibe das Originalbild mit dem skalierten Bild
            cv2.imwrite(image_path, resized_image)
            print(f"Bild skaliert und gespeichert: {image_path}")

print("Skalierung für alle Klassen abgeschlossen.")
# Out:
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_1.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_10.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_11.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_12.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_13.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_14.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_15.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_16.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_17.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_2.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_3.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_4.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_5.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_6.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_7.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_8.png
# Bild skaliert und gespeichert: picks/dataset/train\rechts_abbiegen\input\mask_9.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_1.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_10.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_11.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_12.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_13.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_14.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_15.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_16.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_17.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_2.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_3.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_4.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_5.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_6.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_7.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_8.png
# Bild skaliert und gespeichert: picks/dataset/train\links_abbiegen\input\mask_9.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_1.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_10.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_11.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_12.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_13.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_14.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_15.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_16.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_17.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_18.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_19.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_2.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_20.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_21.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_22.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_23.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_24.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_3.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_4.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_5.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_6.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_7.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_8.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus\input\mask_9.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_1.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_10.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_11.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_12.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_13.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_14.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_15.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_16.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_17.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_18.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_19.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_2.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_20.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_21.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_22.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_23.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_24.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_3.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_4.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_5.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_6.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_7.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_8.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_rechts\input\mask_9.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_1.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_10.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_11.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_12.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_13.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_14.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_15.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_16.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_17.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_18.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_19.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_2.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_20.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_21.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_22.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_23.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_24.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_3.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_4.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_5.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_6.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_7.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_8.png
# Bild skaliert und gespeichert: picks/dataset/train\geradeaus_links\input\mask_9.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_1.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_10.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_11.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_12.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_13.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_14.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_15.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_16.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_17.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_18.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_19.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_2.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_20.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_3.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_4.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_5.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_6.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_7.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_8.png
# Bild skaliert und gespeichert: picks/dataset/train\zebrastreifen\input\mask_9.png
# Skalierung für alle Klassen abgeschlossen.

# %%
import os
import shutil
import random

# Basisverzeichnis
base_dir = r"C:\Uni\python\masked autoencoder\picks\dataset\train"

# Klassenordner
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen"
]

# Verarbeitung der Klassen
for class_name in classes:
    class_path = os.path.join(base_dir, class_name)
    input_dir = os.path.join(class_path, "input")
    output_dir = os.path.join(class_path, "output")
    nicht_sauber_dir = os.path.join(class_path, "nicht_sauber")

    # Erstelle die Ordner, falls sie nicht existieren
    os.makedirs(input_dir, exist_ok=True)
    os.makedirs(output_dir, exist_ok=True)

    # Sammle existierende mask_*.png und clear_*.png, um Nummern zu vermeiden
    existing_mask_numbers = {
        int(f.split("_")[1].split(".")[0])
        for f in os.listdir(input_dir) if f.startswith("mask_") and f.endswith(".png")
    }
    existing_clear_numbers = {
        int(f.split("_")[1].split(".")[0])
        for f in os.listdir(output_dir) if f.startswith("clear_") and f.endswith(".png")
    }

    # Maximal verwendete Nummern bestimmen
    max_mask_number = max(existing_mask_numbers, default=0)
    max_clear_number = max(existing_clear_numbers, default=0)

    # Verarbeite Bilder aus 'nicht_sauber/'
    if os.path.exists(nicht_sauber_dir):
        for file_name in os.listdir(nicht_sauber_dir):
            file_path = os.path.join(nicht_sauber_dir, file_name)

            # Neue Nummer für 'mask_*.png'
            max_mask_number += 1
            new_mask_name = f"mask_{max_mask_number}.png"
            new_mask_path = os.path.join(input_dir, new_mask_name)

            # Verschiebe Bild in 'input/' und benenne es um
            shutil.move(file_path, new_mask_path)

            # Zufälliges Bild aus 'output/' zuordnen, das noch keinen 'clear_*.png'-Namen hat
            output_candidates = [
                f for f in os.listdir(output_dir)
                if not f.startswith("clear_") and f.endswith(".png")
            ]

            if output_candidates:
                assigned_output = random.choice(output_candidates)
                assigned_output_path = os.path.join(output_dir, assigned_output)

                # Neue Nummer für 'clear_*.png'
                max_clear_number += 1
                new_clear_name = f"clear_{max_clear_number}.png"
                new_clear_path = os.path.join(output_dir, new_clear_name)

                # Benenne das zugewiesene Bild im 'output/'-Ordner um
                os.rename(assigned_output_path, new_clear_path)

        print(f"'{class_name}': {len(os.listdir(nicht_sauber_dir))} Bilder aus 'nicht_sauber/' verarbeitet.")

print("Alle Bilder erfolgreich verschoben und umbenannt!")
# Out:
# 'rechts_abbiegen': 0 Bilder aus 'nicht_sauber/' verarbeitet.
# 'links_abbiegen': 0 Bilder aus 'nicht_sauber/' verarbeitet.
# 'geradeaus': 0 Bilder aus 'nicht_sauber/' verarbeitet.
# 'geradeaus_rechts': 0 Bilder aus 'nicht_sauber/' verarbeitet.
# 'geradeaus_links': 0 Bilder aus 'nicht_sauber/' verarbeitet.
# 'zebrastreifen': 0 Bilder aus 'nicht_sauber/' verarbeitet.
# Alle Bilder erfolgreich verschoben und umbenannt!

# %%
import os
import cv2
import numpy as np
import random

# Basisverzeichnisse
base_dir = r"picks/dataset/temp/zebra"
traffic_signs_dir = os.path.join(base_dir, "output")          # Originalbilder (zugeschnitten)
masks_pflanzen_dir = r"picks/masks_pflanzen"                  # Masken für Pflanzen
input_pflanzen_dir = os.path.join(base_dir, "input")          # Maskierte Bilder durch Pflanzen

# Erstelle die Ausgabeverzeichnisse, falls sie nicht existieren
os.makedirs(input_pflanzen_dir, exist_ok=True)

# Zielgröße der Bilder
image_size = (64, 64)

# Wichtige Bereiche für 'geradeaus_rechts' (Safe Zone)
safe_zone = (0.3, 0.7, 0.3, 0.7)  # Format: (y1_ratio, y2_ratio, x1_ratio, x2_ratio)

# Funktion zur Auswahl eines zufälligen Bereichs aus einem Maskenbild
def extract_random_section(mask, max_size=(20, 20)):
    mask_h, mask_w = mask.shape[:2]
    section_w = random.randint(10, max_size[0])
    section_h = random.randint(10, max_size[1])

    if mask_h <= section_h or mask_w <= section_w:
        return mask  # Wenn die Maske kleiner ist, verwende die gesamte Maske

    x1 = random.randint(0, mask_w - section_w)
    y1 = random.randint(0, mask_h - section_h)
    return mask[y1:y1+section_h, x1:x1+section_w]

# Funktion zur Maskierung eines Verkehrszeichenbilds
def create_masked_image(traffic_sign_path, masks, new_clear_number, new_mask_number, safe_zone, input_dir, output_dir, num_masks=5):
    # Lade das Verkehrszeichenbild
    traffic_sign = cv2.imread(traffic_sign_path)
    if traffic_sign is None:
        raise FileNotFoundError(f"Das Verkehrszeichenbild '{traffic_sign_path}' konnte nicht geladen werden.")

    h, w, _ = traffic_sign.shape
    y1_safe, y2_safe, x1_safe, x2_safe = int(h * safe_zone[0]), int(h * safe_zone[1]), int(w * safe_zone[2]), int(w * safe_zone[3])

    # Verkehrszeichenbild kopieren
    masked_image = traffic_sign.copy()

    # Füge mehrere Masken hinzu
    for _ in range(num_masks):
        mask_path = random.choice(masks)
        mask = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)  # Lade mit Alphakanal

        # Extrahiere einen zufälligen Bereich aus der Maske
        mask_section = extract_random_section(mask, max_size=(20, 20))
        mask_h, mask_w = mask_section.shape[:2]

        # Wähle eine zufällige Position außerhalb der Safe Zone
        while True:
            x = random.randint(0, w - mask_w)
            y = random.randint(0, h - mask_h)

            if not (x < x2_safe and x + mask_w > x1_safe and y < y2_safe and y + mask_h > y1_safe):
                break

        # Überlagere den Abschnitt auf das Verkehrszeichenbild
        alpha = mask_section[:, :, 3] / 255.0 if mask_section.shape[2] == 4 else 0.5  # Transparenz
        for c in range(3):  # Für die RGB-Kanäle
            masked_image[y:y+mask_h, x:x+mask_w, c] = (
                alpha * mask_section[:, :, c] + (1 - alpha) * masked_image[y:y+mask_h, x:x+mask_w, c]
            )

    # Speicher das maskierte Bild im `input`-Ordner
    new_mask_name = f"mask_{new_mask_number}.png"
    input_path = os.path.join(input_dir, new_mask_name)
    cv2.imwrite(input_path, masked_image)

    # Benenne das Originalbild im `output`-Ordner um
    new_clear_name = f"clear_{new_clear_number}.png"
    new_clear_path = os.path.join(output_dir, new_clear_name)
    os.rename(traffic_sign_path, new_clear_path)

    print(f"Bilder verarbeitet: Original -> {new_clear_path}, Maskiert -> {input_path}")

# Maskieren der Verkehrszeichen
masks = [os.path.join(masks_pflanzen_dir, f) for f in os.listdir(masks_pflanzen_dir) if f.endswith(".png")]

# Sammle bestehende `clear_num`- und `mask_num`-Nummern
existing_clear_numbers = {
    int(f.split("_")[1].split(".")[0])
    for f in os.listdir(traffic_signs_dir) if f.startswith("clear_") and f.endswith(".png")
}
existing_mask_numbers = {
    int(f.split("_")[1].split(".")[0])
    for f in os.listdir(input_pflanzen_dir) if f.startswith("mask_") and f.endswith(".png")
}

max_clear_number = max(existing_clear_numbers, default=0)
max_mask_number = max(existing_mask_numbers, default=0)

# Bearbeite nur die Bilder, die nicht `clear_*.png` heißen
output_images = [
    f for f in os.listdir(traffic_signs_dir)
    if not f.startswith("clear_") and f.endswith(".png")
]

for idx, traffic_sign_file in enumerate(output_images, start=1):
    traffic_sign_path = os.path.join(traffic_signs_dir, traffic_sign_file)

    # Aktualisiere die neuen Nummern
    max_clear_number += 1
    max_mask_number += 1

    # Erstelle die maskierten Bilder
    create_masked_image(
        traffic_sign_path, masks, max_clear_number, max_mask_number,
        safe_zone, input_pflanzen_dir, traffic_signs_dir, num_masks=5
    )

print("Maskierung abgeschlossen!")
# Out:
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_10.png, Maskiert -> picks/dataset/temp/zebra\input\mask_10.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_11.png, Maskiert -> picks/dataset/temp/zebra\input\mask_11.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_12.png, Maskiert -> picks/dataset/temp/zebra\input\mask_12.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_13.png, Maskiert -> picks/dataset/temp/zebra\input\mask_13.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_14.png, Maskiert -> picks/dataset/temp/zebra\input\mask_14.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_15.png, Maskiert -> picks/dataset/temp/zebra\input\mask_15.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_16.png, Maskiert -> picks/dataset/temp/zebra\input\mask_16.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_17.png, Maskiert -> picks/dataset/temp/zebra\input\mask_17.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_18.png, Maskiert -> picks/dataset/temp/zebra\input\mask_18.png
# Bilder verarbeitet: Original -> picks/dataset/temp/zebra\output\clear_19.png, Maskiert -> picks/dataset/temp/zebra\input\mask_19.png
# Maskierung abgeschlossen!

# %%
import os
import cv2
import numpy as np
import random

# Basisverzeichnis
base_dir = r"picks/dataset/train"

# Klassen und ihre Safe Zones
classes_safe_zones = {
    "rechts_abbiegen": (0.3, 0.7, 0.3, 0.7),  # Safe Zone (y1_ratio, y2_ratio, x1_ratio, x2_ratio)
    "links_abbiegen": (0.3, 0.7, 0.3, 0.7),
    "geradeaus": (0.3, 0.7, 0.4, 0.6),
    "geradeaus_rechts": (0.3, 0.7, 0.4, 0.6),
    "geradeaus_links": (0.3, 0.7, 0.4, 0.6),
    "zebrastreifen": (0.4, 0.6, 0.4, 0.6),
}

# Verzeichnis mit Masken
masks_pflanzen_dir = r"picks/masks_pflanzen"

# Zielgröße der Bilder
image_size = (64, 64)

# Funktion zur Auswahl eines zufälligen Bereichs aus einem Maskenbild
def extract_random_section(mask, max_size=(20, 20)):
    mask_h, mask_w = mask.shape[:2]
    section_w = random.randint(10, max_size[0])
    section_h = random.randint(10, max_size[1])

    if mask_h <= section_h or mask_w <= section_w:
        return mask  # Wenn die Maske kleiner ist, verwende die gesamte Maske

    x1 = random.randint(0, mask_w - section_w)
    y1 = random.randint(0, mask_h - section_h)
    return mask[y1:y1+section_h, x1:x1+section_w]

# Funktion zur Maskierung eines Verkehrszeichenbilds
def create_masked_image(traffic_sign_path, masks, new_clear_number, new_mask_number, safe_zone, input_dir, output_dir, num_masks=6):
    # Lade das Verkehrszeichenbild
    traffic_sign = cv2.imread(traffic_sign_path)
    if traffic_sign is None:
        raise FileNotFoundError(f"Das Verkehrszeichenbild '{traffic_sign_path}' konnte nicht geladen werden.")

    h, w, _ = traffic_sign.shape
    y1_safe, y2_safe, x1_safe, x2_safe = int(h * safe_zone[0]), int(h * safe_zone[1]), int(w * safe_zone[2]), int(w * safe_zone[3])

    # Verkehrszeichenbild kopieren
    masked_image = traffic_sign.copy()

    # Füge mehrere Masken hinzu
    for _ in range(num_masks):
        mask_path = random.choice(masks)
        mask = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)  # Lade mit Alphakanal

        # Extrahiere einen zufälligen Bereich aus der Maske
        mask_section = extract_random_section(mask, max_size=(20, 20))
        mask_h, mask_w = mask_section.shape[:2]

        # Wähle eine zufällige Position außerhalb der Safe Zone
        while True:
            x = random.randint(0, w - mask_w)
            y = random.randint(0, h - mask_h)

            if not (x < x2_safe and x + mask_w > x1_safe and y < y2_safe and y + mask_h > y1_safe):
                break

        # Überlagere den Abschnitt auf das Verkehrszeichenbild
        alpha = mask_section[:, :, 3] / 255.0 if mask_section.shape[2] == 4 else 0.5  # Transparenz
        for c in range(3):  # Für die RGB-Kanäle
            masked_image[y:y+mask_h, x:x+mask_w, c] = (
                alpha * mask_section[:, :, c] + (1 - alpha) * masked_image[y:y+mask_h, x:x+mask_w, c]
            )

    # Speicher das maskierte Bild im `input`-Ordner
    new_mask_name = f"mask_{new_mask_number}.png"
    input_path = os.path.join(input_dir, new_mask_name)
    cv2.imwrite(input_path, masked_image)

    # Benenne das Originalbild im `output`-Ordner um
    new_clear_name = f"clear_{new_clear_number}.png"
    new_clear_path = os.path.join(output_dir, new_clear_name)
    os.rename(traffic_sign_path, new_clear_path)

    print(f"Bilder verarbeitet: Original -> {new_clear_path}, Maskiert -> {input_path}")

# Lade die Masken
masks = [os.path.join(masks_pflanzen_dir, f) for f in os.listdir(masks_pflanzen_dir) if f.endswith(".png")]

# Verarbeitung für alle Klassen
for class_name, safe_zone in classes_safe_zones.items():
    print(f"Verarbeite Klasse: {class_name}")

    # Verzeichnisse für die Klasse
    class_dir = os.path.join(base_dir, class_name)
    traffic_signs_dir = os.path.join(class_dir, "output")
    input_pflanzen_dir = os.path.join(class_dir, "input")

    # Erstelle die Eingabeverzeichnisse, falls sie nicht existieren
    os.makedirs(input_pflanzen_dir, exist_ok=True)

    # Sammle bestehende `clear_num`- und `mask_num`-Nummern
    existing_clear_numbers = {
        int(f.split("_")[1].split(".")[0])
        for f in os.listdir(traffic_signs_dir) if f.startswith("clear_") and f.endswith(".png")
    }
    existing_mask_numbers = {
        int(f.split("_")[1].split(".")[0])
        for f in os.listdir(input_pflanzen_dir) if f.startswith("mask_") and f.endswith(".png")
    }

    max_clear_number = max(existing_clear_numbers, default=0)
    max_mask_number = max(existing_mask_numbers, default=0)

    # Bearbeite nur die Bilder, die nicht `clear_*.png` heißen
    output_images = [
        f for f in os.listdir(traffic_signs_dir)
        if not f.startswith("clear_") and f.endswith(".png")
    ]

    for traffic_sign_file in output_images:
        traffic_sign_path = os.path.join(traffic_signs_dir, traffic_sign_file)

        # Aktualisiere die neuen Nummern
        max_clear_number += 1
        max_mask_number += 1

        # Erstelle die maskierten Bilder
        create_masked_image(
            traffic_sign_path, masks, max_clear_number, max_mask_number,
            safe_zone, input_pflanzen_dir, traffic_signs_dir, 5
        )

print("Maskierung für alle Klassen abgeschlossen!")
# Out:
# Verarbeite Klasse: rechts_abbiegen
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_501.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_501.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_502.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_502.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_503.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_503.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_504.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_504.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_505.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_505.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_506.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_506.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_507.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_507.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_508.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_508.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_509.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_509.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_510.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_510.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_511.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_511.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_512.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_512.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_513.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_513.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_514.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_514.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_515.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_515.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_516.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_516.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_517.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_517.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_518.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_518.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_519.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_519.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_520.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_520.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_521.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_521.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_522.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_522.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_523.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_523.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_524.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_524.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_525.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_525.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_526.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_526.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_527.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_527.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_528.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_528.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_529.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_529.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_530.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_530.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_531.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_531.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_532.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_532.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_533.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_533.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_534.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_534.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_535.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_535.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_536.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_536.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_537.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_537.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_538.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_538.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_539.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_539.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_540.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_540.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_541.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_541.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_542.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_542.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_543.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_543.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_544.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_544.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_545.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_545.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_546.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_546.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_547.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_547.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_548.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_548.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_549.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_549.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_550.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_550.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_551.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_551.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_552.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_552.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_553.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_553.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_554.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_554.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_555.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_555.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_556.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_556.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_557.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_557.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_558.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_558.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_559.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_559.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_560.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_560.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_561.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_561.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_562.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_562.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_563.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_563.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_564.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_564.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_565.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_565.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_566.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_566.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_567.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_567.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_568.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_568.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_569.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_569.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_570.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_570.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_571.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_571.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_572.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_572.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_573.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_573.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_574.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_574.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_575.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_575.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_576.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_576.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_577.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_577.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_578.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_578.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_579.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_579.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_580.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_580.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_581.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_581.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_582.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_582.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_583.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_583.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_584.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_584.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_585.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_585.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_586.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_586.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_587.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_587.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_588.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_588.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_589.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_589.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_590.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_590.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_591.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_591.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_592.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_592.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_593.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_593.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_594.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_594.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_595.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_595.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_596.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_596.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_597.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_597.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_598.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_598.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_599.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_599.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_600.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_600.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_601.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_601.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_602.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_602.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_603.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_603.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_604.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_604.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_605.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_605.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_606.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_606.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_607.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_607.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_608.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_608.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_609.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_609.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_610.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_610.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_611.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_611.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_612.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_612.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_613.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_613.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_614.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_614.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_615.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_615.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_616.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_616.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_617.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_617.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_618.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_618.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_619.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_619.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_620.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_620.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_621.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_621.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_622.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_622.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_623.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_623.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_624.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_624.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_625.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_625.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_626.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_626.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_627.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_627.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_628.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_628.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_629.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_629.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_630.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_630.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_631.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_631.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_632.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_632.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_633.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_633.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_634.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_634.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_635.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_635.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_636.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_636.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_637.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_637.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_638.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_638.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_639.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_639.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_640.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_640.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_641.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_641.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_642.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_642.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_643.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_643.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_644.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_644.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_645.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_645.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_646.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_646.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_647.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_647.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_648.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_648.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_649.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_649.png
# Bilder verarbeitet: Original -> picks/dataset/train\rechts_abbiegen\output\clear_650.png, Maskiert -> picks/dataset/train\rechts_abbiegen\input\mask_650.png
# Verarbeite Klasse: links_abbiegen
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_501.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_501.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_502.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_502.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_503.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_503.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_504.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_504.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_505.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_505.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_506.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_506.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_507.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_507.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_508.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_508.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_509.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_509.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_510.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_510.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_511.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_511.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_512.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_512.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_513.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_513.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_514.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_514.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_515.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_515.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_516.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_516.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_517.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_517.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_518.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_518.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_519.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_519.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_520.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_520.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_521.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_521.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_522.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_522.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_523.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_523.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_524.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_524.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_525.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_525.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_526.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_526.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_527.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_527.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_528.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_528.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_529.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_529.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_530.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_530.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_531.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_531.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_532.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_532.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_533.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_533.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_534.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_534.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_535.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_535.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_536.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_536.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_537.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_537.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_538.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_538.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_539.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_539.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_540.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_540.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_541.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_541.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_542.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_542.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_543.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_543.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_544.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_544.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_545.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_545.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_546.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_546.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_547.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_547.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_548.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_548.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_549.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_549.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_550.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_550.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_551.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_551.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_552.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_552.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_553.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_553.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_554.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_554.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_555.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_555.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_556.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_556.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_557.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_557.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_558.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_558.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_559.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_559.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_560.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_560.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_561.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_561.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_562.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_562.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_563.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_563.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_564.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_564.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_565.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_565.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_566.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_566.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_567.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_567.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_568.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_568.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_569.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_569.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_570.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_570.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_571.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_571.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_572.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_572.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_573.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_573.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_574.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_574.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_575.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_575.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_576.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_576.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_577.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_577.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_578.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_578.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_579.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_579.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_580.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_580.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_581.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_581.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_582.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_582.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_583.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_583.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_584.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_584.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_585.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_585.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_586.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_586.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_587.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_587.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_588.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_588.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_589.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_589.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_590.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_590.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_591.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_591.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_592.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_592.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_593.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_593.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_594.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_594.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_595.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_595.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_596.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_596.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_597.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_597.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_598.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_598.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_599.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_599.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_600.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_600.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_601.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_601.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_602.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_602.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_603.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_603.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_604.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_604.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_605.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_605.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_606.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_606.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_607.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_607.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_608.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_608.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_609.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_609.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_610.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_610.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_611.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_611.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_612.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_612.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_613.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_613.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_614.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_614.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_615.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_615.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_616.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_616.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_617.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_617.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_618.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_618.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_619.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_619.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_620.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_620.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_621.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_621.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_622.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_622.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_623.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_623.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_624.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_624.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_625.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_625.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_626.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_626.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_627.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_627.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_628.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_628.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_629.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_629.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_630.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_630.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_631.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_631.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_632.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_632.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_633.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_633.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_634.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_634.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_635.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_635.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_636.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_636.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_637.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_637.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_638.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_638.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_639.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_639.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_640.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_640.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_641.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_641.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_642.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_642.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_643.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_643.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_644.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_644.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_645.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_645.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_646.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_646.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_647.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_647.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_648.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_648.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_649.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_649.png
# Bilder verarbeitet: Original -> picks/dataset/train\links_abbiegen\output\clear_650.png, Maskiert -> picks/dataset/train\links_abbiegen\input\mask_650.png
# Verarbeite Klasse: geradeaus
# Bilder verarbeitet: Original -> picks/dataset/train\geradeaus\output\clear_501.png, Maskiert -> picks/dataset/train\geradeaus\input\mask_501.png
# Bilder verarbeitet: Original -> picks/dataset/train\geradeaus\output\clear_502.png, Maskiert -> picks/dataset/train\geradeaus\input\mask_502.png
# Bilder verarbeitet: Original -> picks/dataset/train\geradeaus\output\clear_503.png, Maskiert -> picks/dataset/train\geradeaus\input\mask_503.png
# Bilder verarbeitet: Original -> picks/dataset/train\geradeaus\output\clear_504.png, Maskiert -> picks/dataset/train\geradeaus\input\mask_504.png
# Bilder verarbeitet: Original -> picks/dataset/train\geradeaus\output\clear_505.png, Maskiert -> picks/dataset/train\geradeaus\input\mask_505.png
# Bilder verarbeitet: Original -> picks/dataset/train\geradeaus\output\clear_506.png, Maskiert -> picks/dataset/train\geradeaus\input\mask_506.png
# Bilder verarbeitet: Original -> picks/dataset/train\geradeaus\output\clear_507.png, Maskiert -> picks/dataset/train\geradeaus\input\mask_507.png
# ...
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_547.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_547.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_548.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_548.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_549.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_549.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_550.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_550.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_551.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_551.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_552.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_552.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_553.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_553.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_554.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_554.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_555.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_555.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_556.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_556.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_557.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_557.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_558.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_558.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_559.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_559.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_560.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_560.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_561.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_561.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_562.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_562.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_563.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_563.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_564.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_564.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_565.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_565.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_566.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_566.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_567.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_567.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_568.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_568.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_569.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_569.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_570.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_570.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_571.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_571.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_572.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_572.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_573.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_573.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_574.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_574.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_575.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_575.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_576.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_576.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_577.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_577.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_578.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_578.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_579.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_579.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_580.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_580.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_581.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_581.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_582.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_582.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_583.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_583.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_584.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_584.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_585.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_585.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_586.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_586.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_587.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_587.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_588.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_588.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_589.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_589.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_590.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_590.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_591.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_591.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_592.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_592.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_593.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_593.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_594.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_594.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_595.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_595.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_596.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_596.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_597.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_597.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_598.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_598.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_599.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_599.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_600.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_600.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_601.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_601.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_602.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_602.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_603.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_603.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_604.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_604.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_605.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_605.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_606.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_606.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_607.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_607.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_608.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_608.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_609.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_609.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_610.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_610.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_611.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_611.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_612.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_612.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_613.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_613.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_614.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_614.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_615.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_615.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_616.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_616.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_617.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_617.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_618.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_618.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_619.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_619.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_620.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_620.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_621.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_621.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_622.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_622.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_623.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_623.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_624.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_624.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_625.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_625.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_626.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_626.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_627.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_627.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_628.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_628.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_629.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_629.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_630.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_630.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_631.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_631.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_632.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_632.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_633.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_633.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_634.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_634.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_635.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_635.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_636.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_636.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_637.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_637.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_638.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_638.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_639.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_639.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_640.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_640.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_641.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_641.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_642.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_642.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_643.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_643.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_644.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_644.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_645.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_645.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_646.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_646.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_647.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_647.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_648.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_648.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_649.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_649.png
# Bilder verarbeitet: Original -> picks/dataset/train\zebrastreifen\output\clear_650.png, Maskiert -> picks/dataset/train\zebrastreifen\input\mask_650.png
# Maskierung für alle Klassen abgeschlossen!

# %%
import os
import random
import shutil

# Basisverzeichnisse
base_train_dir = r"picks/dataset/train"
base_val_dir = r"picks/dataset/val"

# Klassen
classes = [
    "rechts_abbiegen",
    "links_abbiegen",
    "geradeaus",
    "geradeaus_rechts",
    "geradeaus_links",
    "zebrastreifen"
]

# Funktion zum Verschieben der Bilder
def move_images_to_val(train_dir, val_dir, percentage=15):
    for class_name in classes:
        print(f"Verarbeite Klasse: {class_name}")

        # Verzeichnisse für die Klasse
        train_class_dir = os.path.join(train_dir, class_name)
        val_class_dir = os.path.join(val_dir, class_name)

        # Output- und Input-Verzeichnisse
        train_output_dir = os.path.join(train_class_dir, "output")
        train_input_dir = os.path.join(train_class_dir, "input")
        val_output_dir = os.path.join(val_class_dir, "output")
        val_input_dir = os.path.join(val_class_dir, "input")

        # Erstelle die Zielverzeichnisse, falls sie nicht existieren
        os.makedirs(val_output_dir, exist_ok=True)
        os.makedirs(val_input_dir, exist_ok=True)

        # Sammle alle Dateien im `output`-Ordner
        output_files = [
            f for f in os.listdir(train_output_dir)
            if f.startswith("clear_") and f.endswith(".png")
        ]

        # Berechne die Anzahl der zu verschiebenden Dateien
        num_to_move = int(len(output_files) * (percentage / 100))
        files_to_move = random.sample(output_files, num_to_move)

        # Verschiebe die Dateien und ihre entsprechenden Masken
        for output_file in files_to_move:
            # Pfade für das `output`-Bild
            train_output_path = os.path.join(train_output_dir, output_file)
            val_output_path = os.path.join(val_output_dir, output_file)

            # Verschiebe das `output`-Bild
            shutil.move(train_output_path, val_output_path)

            # Bestimme den korrespondierenden Maskennamen im `input`-Ordner
            mask_number = output_file.split("_")[1].split(".")[0]  # Extrahiere die Nummer
            mask_file = f"mask_{mask_number}.png"

            # Pfade für die Maske
            train_mask_path = os.path.join(train_input_dir, mask_file)
            val_mask_path = os.path.join(val_input_dir, mask_file)

            # Verschiebe die Maske
            if os.path.exists(train_mask_path):
                shutil.move(train_mask_path, val_mask_path)
            else:
                print(f"Warnung: Maske '{mask_file}' fehlt für '{output_file}'")

        print(f"Klasse '{class_name}': {num_to_move} Bilder erfolgreich verschoben.")

# Verschiebe 15 % der Bilder von `train` nach `val`
move_images_to_val(base_train_dir, base_val_dir, percentage=15)
print("Verschieben abgeschlossen!")
# Out:
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_38_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_38_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_38_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_38_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_248_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_248_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_248_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_248_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_70_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_70_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_70_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_70_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_494_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_494_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_494_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_494_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_424_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_424_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_424_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_424_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_22_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_22_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_22_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_22_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_62_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_62_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_62_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_62_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_97_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_97_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_97_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_97_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_56_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_56_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_56_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_56_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_181_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_181_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_181_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_181_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_450_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_450_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_450_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_450_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_430_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_430_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_430_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_430_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_250_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_250_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_250_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_250_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_111_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_111_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_111_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_111_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_18_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_18_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_18_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_18_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_275_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_275_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_275_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_275_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_236_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_236_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_236_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_236_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_139_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_139_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_139_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_139_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_495_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_495_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_495_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_495_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_295_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_295_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_295_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_295_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_372_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_372_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_372_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_372_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_474_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_474_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_474_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_474_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_452_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_452_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_452_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_452_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_161_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_161_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_161_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_161_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_65_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_65_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_65_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_65_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_166_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_166_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_166_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_166_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_365_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_365_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_365_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_365_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_390_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_390_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_390_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_390_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_426_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_426_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_426_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_426_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_266_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_266_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_266_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_266_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_223_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_223_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_223_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_223_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_126_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_126_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_126_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_126_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_404_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_404_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_404_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_404_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_421_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_421_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_421_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_421_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_203_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_203_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_203_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_203_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_115_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_115_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_115_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_115_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_412_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_412_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_412_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_412_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_179_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_179_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_179_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_179_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_304_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_304_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_304_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_304_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_238_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_238_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_238_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_238_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_401_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_401_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_401_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_401_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_25_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_25_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_25_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_25_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_141_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_141_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_141_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_141_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_361_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_361_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_361_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_361_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_337_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_337_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_337_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_337_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_396_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_396_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_396_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_396_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_481_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_481_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_481_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_481_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_386_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_386_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_386_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_386_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_59_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_59_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_59_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_59_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_217_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_217_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_217_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_217_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_14_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_14_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_14_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_14_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_354_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_354_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_354_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_354_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_237_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_237_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_237_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_237_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_196_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_196_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_196_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_196_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_127_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_127_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_127_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_127_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_87_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_87_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_87_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_87_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_189_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_189_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_189_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_189_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_463_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_463_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_463_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_463_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_216_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_216_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_216_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_216_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_482_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_482_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_482_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_482_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_49_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_49_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_49_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_49_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_89_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_89_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_89_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_89_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_191_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_191_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_191_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_191_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_289_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_289_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_289_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_289_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_82_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_82_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_82_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_82_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_135_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_135_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_135_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_135_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_58_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_58_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_58_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_58_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_100_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_100_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_100_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_100_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_76_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_76_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_76_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_76_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_292_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_292_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_292_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_292_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_399_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_399_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_399_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_399_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_144_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_144_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_144_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_144_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_78_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_78_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_78_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_78_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_57_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_57_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_57_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_57_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_autos\cropped_418_auto.png -> picks/dataset/val\rechts_abbiegen\input_autos\cropped_418_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\rechts_abbiegen\input_pflanzen\cropped_418_pflanze.png -> picks/dataset/val\rechts_abbiegen\input_pflanzen\cropped_418_pflanze.png
# 75 Dateien (inkl. Masken) wurden aus 'picks/dataset/train\rechts_abbiegen\output' nach 'picks/dataset/val\rechts_abbiegen\output' verschoben.
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_474_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_474_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_474_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_474_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_484_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_484_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_484_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_484_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_364_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_364_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_364_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_364_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_413_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_413_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_413_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_413_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_463_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_463_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_463_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_463_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_239_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_239_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_239_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_239_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_252_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_252_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_252_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_252_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_136_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_136_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_136_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_136_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_266_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_266_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_266_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_266_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_379_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_379_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_379_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_379_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_258_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_258_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_258_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_258_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_181_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_181_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_181_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_181_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_139_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_139_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_139_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_139_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_251_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_251_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_251_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_251_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_272_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_272_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_272_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_272_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_494_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_494_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_494_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_494_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_66_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_66_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_66_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_66_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_133_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_133_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_133_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_133_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_21_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_21_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_21_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_21_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_350_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_350_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_350_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_350_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_339_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_339_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_339_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_339_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_233_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_233_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_233_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_233_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_106_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_106_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_106_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_106_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_218_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_218_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_218_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_218_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_201_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_201_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_201_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_201_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_283_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_283_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_283_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_283_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_24_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_24_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_24_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_24_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_62_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_62_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_62_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_62_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_202_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_202_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_202_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_202_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_335_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_335_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_335_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_335_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_78_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_78_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_78_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_78_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_191_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_191_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_191_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_191_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_488_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_488_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_488_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_488_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_311_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_311_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_311_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_311_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_141_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_141_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_141_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_141_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_79_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_79_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_79_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_79_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_472_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_472_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_472_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_472_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_489_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_489_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_489_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_489_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_319_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_319_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_319_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_319_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_496_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_496_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_496_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_496_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_369_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_369_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_369_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_369_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_49_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_49_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_49_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_49_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_225_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_225_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_225_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_225_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_147_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_147_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_147_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_147_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_246_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_246_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_246_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_246_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_19_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_19_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_19_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_19_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_180_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_180_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_180_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_180_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_439_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_439_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_439_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_439_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_449_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_449_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_449_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_449_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_12_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_12_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_12_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_12_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_303_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_303_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_303_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_303_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_164_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_164_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_164_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_164_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_70_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_70_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_70_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_70_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_354_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_354_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_354_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_354_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_244_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_244_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_244_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_244_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_450_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_450_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_450_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_450_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_3_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_3_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_3_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_3_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_168_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_168_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_168_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_168_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_144_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_144_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_144_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_144_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_491_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_491_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_491_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_491_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_140_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_140_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_140_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_140_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_368_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_368_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_368_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_368_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_290_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_290_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_290_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_290_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_461_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_461_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_461_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_461_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_428_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_428_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_428_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_428_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_457_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_457_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\links_abbiegen\input_pflanzen\cropped_457_pflanze.png -> picks/dataset/val\links_abbiegen\input_pflanzen\cropped_457_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\links_abbiegen\input_autos\cropped_95_auto.png -> picks/dataset/val\links_abbiegen\input_autos\cropped_95_auto.png
# ...
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_318_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_318_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_469_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_469_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_469_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_469_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_120_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_120_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_120_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_120_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_445_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_445_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_445_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_445_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_235_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_235_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_235_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_235_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_21_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_21_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_21_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_21_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_35_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_35_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_35_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_35_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_257_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_257_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_257_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_257_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_359_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_359_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_359_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_359_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_372_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_372_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_372_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_372_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_2_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_2_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_2_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_2_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_66_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_66_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_66_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_66_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_349_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_349_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_349_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_349_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_244_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_244_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_244_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_244_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_380_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_380_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_380_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_380_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_442_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_442_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_442_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_442_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_485_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_485_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_485_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_485_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_115_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_115_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_115_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_115_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_275_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_275_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_275_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_275_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_51_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_51_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_51_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_51_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_274_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_274_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_274_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_274_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_497_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_497_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_497_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_497_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_283_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_283_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_283_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_283_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_306_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_306_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_306_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_306_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_122_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_122_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_122_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_122_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_53_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_53_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_53_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_53_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_428_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_428_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_428_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_428_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_263_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_263_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_263_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_263_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_58_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_58_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_58_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_58_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_449_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_449_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_449_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_449_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_300_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_300_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_300_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_300_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_69_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_69_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_69_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_69_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_249_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_249_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_249_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_249_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_472_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_472_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_472_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_472_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_381_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_381_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_381_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_381_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_95_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_95_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_95_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_95_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_17_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_17_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_17_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_17_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_146_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_146_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_146_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_146_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_106_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_106_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_106_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_106_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_453_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_453_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_453_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_453_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_392_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_392_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_392_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_392_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_169_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_169_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_169_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_169_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_481_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_481_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_481_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_481_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_71_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_71_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_71_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_71_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_334_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_334_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_334_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_334_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_24_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_24_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_24_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_24_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_238_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_238_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_238_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_238_pflanze.png
# Auto-Maske verschoben: picks/dataset/train\zebrastreifen\input_autos\cropped_229_auto.png -> picks/dataset/val\zebrastreifen\input_autos\cropped_229_auto.png
# Pflanzen-Maske verschoben: picks/dataset/train\zebrastreifen\input_pflanzen\cropped_229_pflanze.png -> picks/dataset/val\zebrastreifen\input_pflanzen\cropped_229_pflanze.png
# 75 Dateien (inkl. Masken) wurden aus 'picks/dataset/train\zebrastreifen\output' nach 'picks/dataset/val\zebrastreifen\output' verschoben.
# Daten erfolgreich aufgeteilt!

# %%
import os

# Funktion zur Berechnung der Gesamtgröße eines Ordners
def get_folder_size(folder):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(folder):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total_size += os.path.getsize(fp)
    return total_size

# Verzeichnisse
train_dir = "picks/dataset/train"
val_dir = "picks/dataset/val"

# Größenberechnung
train_size = get_folder_size(train_dir) / (1024 * 1024)  # In MB
val_size = get_folder_size(val_dir) / (1024 * 1024)  # In MB

print(f"Größe des Train-Datasets: {train_size:.2f} MB")
print(f"Größe des Val-Datasets: {val_size:.2f} MB")
# Out:
# Größe des Train-Datasets: 62.14 MB
# Größe des Val-Datasets: 10.98 MB
